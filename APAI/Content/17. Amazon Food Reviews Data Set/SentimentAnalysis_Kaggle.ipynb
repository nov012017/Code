# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

import wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output

import os
os.chdir('C:\\Users\\Admin\\Desktop\\Analytics Path\\Data\\Sentiment')

# %%
data=pd.read_csv('Sentiment.csv')

# %%
data.head(1)
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
#
#    subject_matter_confidence candidate_gold      ...      relevant_yn_gold  \
# 0                        1.0            NaN      ...                   NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
#
#                tweet_created            tweet_id  tweet_location user_timezone
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN         Quito
#
# [1 rows x 21 columns]

# %%
data=data[['text','sentiment']]

# %%
train,test=train_test_split(data,test_size=0.1 )

# %%
train=train[train['sentiment']!='Neutral']

# %%
train_pos=train[train['sentiment']=='Positive']
train_pos=train_pos['text']
train_neg=train[train['sentiment']=='Negative']
train_neg=train_neg['text']

# %%
def wordcloud_draw(data,color='black'):
    words=' '.join(data)
   # print(words)
    cleaned_word=' '.join([word for word in words.split()
                        if 'http' not in word
                             and  not word.startswith('@')
                             and not word.startswith('#')
                             and word != 'RT'
                        ])
    wordcloud = WordCloud(background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
print("Positive words")
wordcloud_draw(train_pos,'white')
print("Negative words")
wordcloud_draw(train_neg)

# %%
tweets=[]
stopwords_set=set(stopwords.words('english'))

for index, row in train.iterrows():
    words_filtered=[e.lower() for e in row.text.split() if len(e)>=3]
    words_cleaned=[word for word in words_filtered
                        if 'http' not in word
                             and  not word.startswith('@')
                             and not word.startswith('#')
                             and word != 'RT'
                        ]
    words_without_stopwords=[word for word in words_cleaned if not word in stopwords_set]
    tweets.append((words_without_stopwords, row.sentiment))

test_pos = test[ test['sentiment'] == 'Positive']
test_pos = test_pos['text']
test_neg = test[ test['sentiment'] == 'Negative']
test_neg = test_neg['text']

# %%
tweets
# Out:
# [(['disappointed', 'talk', 'called,', 'f**k', 'hair?'], 'Negative'),
#  (['thoughtful'], 'Positive'),
#  (['americans', 'fed', 'lies!', 'lies', 'benefit', 'politicians!'],
#   'Negative'),
#  (['lived', 'florida', 'years', 'jeb', 'bush', 'swear,', 'more...'],
#   'Negative'),
#  (['embarrassing.',
#    'whole',
#    'world',
#    'watching',
#    'must',
#    'asking',
#    'going',
#    'on.'],
#   'Negative'),
#  (['chris', 'christie', 'loser.'], 'Negative'),
#  (['comparing', 'think', 'canadians', 'big', 'winners', 'tonight.'],
#   'Negative'),
#  (['address', 'butcher', 'babies', 'profit!'], 'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['shame',
#    'brett',
#    'baier,',
#    'chris',
#    'wallace,',
#    'today',
#    '50th',
#    'anniversary',
#    'voting',
#    'rights',
#    'act',
#    'question…'],
#   'Negative'),
#  (['debate',
#    'moderators',
#    'unprofessional',
#    'handling',
#    'debate.',
#    'act',
#    'like'],
#   'Negative'),
#  (['megyn',
#    'kelly',
#    'worried',
#    "trump's",
#    'party',
#    'loyalty.',
#    'watched',
#    'transform',
#    'liberal',
#    'hours.'],
#   'Negative'),
#  (['kasich', 'aware', "he's", 'making', 'sense?'], 'Positive'),
#  (['seemed', 'want', 'cult', 'personality', 'ratings', 'substance'],
#   'Negative'),
#  (['donated', 'name'], 'Positive'),
#  (['quit', 'trying', 'make', 'kasich', 'thing.'], 'Negative'),
#  (['truest',
#    'best',
#    'line:',
#    '"if',
#    'weren’t',
#    'wouldn’t',
#    'even',
#    'talking',
#    'illegal',
#    'immigration"'],
#   'Positive'),
#  (['nothing',
#    'really',
#    'matters.',
#    'world',
#    'going',
#    'better',
#    'place,',
#    'need',
#    'total',
#    'sea',
#    'change',
#    'human',
#    'condition'],
#   'Negative'),
#  (['want',
#    'defend',
#    'life,',
#    'cruz,',
#    'make',
#    'sure',
#    'nobody',
#    'dies',
#    'administration',
#    'president!'],
#   'Negative'),
#  (['seriously:',
#    'gop',
#    'voters',
#    'think',
#    'god',
#    'talks',
#    'presidential',
#    'candidates?'],
#   'Negative'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Positive'),
#  (['.@washingtonpost', 'collab', 'pretty', 'awesome', 'annotation', 'cool'],
#   'Positive'),
#  (['yes',
#    "we're",
#    'waiting',
#    'take',
#    'excellent',
#    'performances',
#    'candidates',
#    'horrendous'],
#   'Negative'),
#  (['thought', 'maybe', 'going', 'show'], 'Negative'),
#  (['lol,', 'fun!', 'aghhh', "i'm", 'pumped!', 'nerds', 'favorite', 'sport!!'],
#   'Positive'),
#  (['path',
#    'becoming',
#    'president',
#    'become',
#    'reality',
#    'show',
#    'focused',
#    'shock',
#    'value?'],
#   'Negative'),
#  (['huckabee.'], 'Negative'),
#  (['step', 'fallen', 'dissect', '22nd', 'amendment:'], 'Positive'),
#  (['huckabee',
#    'looks',
#    'like',
#    'one',
#    'muppets',
#    'balcony.',
#    'name',
#    'even',
#    'sounds',
#    'like',
#    'one.'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['came', 'back', 'time.', 'maybe', 'bill', 'watterson', 'well...'],
#   'Negative'),
#  (['dear',
#    'john',
#    'kasich,',
#    'beat',
#    'republican',
#    'friends',
#    'gay',
#    'tree',
#    'branch'],
#   'Positive'),
#  (['please',
#    'stop',
#    'talking',
#    'ronald',
#    'reagan',
#    'way',
#    'ronald',
#    'reagan',
#    'talked',
#    'abraham',
#    'lincoln.'],
#   'Negative'),
#  (['jeb:', 'father', 'was...oh', 'nevermind.', 'parenting', 'overrated.'],
#   'Negative'),
#  (['probably',
#    'funniest',
#    'thing',
#    'whole',
#    'circus',
#    "we're",
#    'calling',
#    '"the',
#    'real',
#    'debate."'],
#   'Negative'),
#  (['get',
#    'world',
#    'deserve,',
#    'gets',
#    'candidates',
#    'deserves.',
#    'like',
#    'trump,',
#    'look',
#    'mirror.'],
#   'Negative'),
#  (['repeal', 'amen!!!'], 'Positive'),
#  (['really',
#    'worth',
#    'mentioning',
#    'reagan',
#    'thing?',
#    'know',
#    'correlation',
#    'causation',
#    'different',
#    'things,',
#    'right?'],
#   'Negative'),
#  (['absolutely!', 'refuse', 'allow', 'speak', 'me.', "i'll", 'draw', 'conc…'],
#   'Negative'),
#  (['senator',
#    'cruz,',
#    'word',
#    'god?',
#    'spit',
#    'tequila.',
#    'damn',
#    'megyn',
#    'kelly,',
#    'expensive',
#    'kind.'],
#   'Negative'),
#  (['.@bobbyjindal',
#    'brags',
#    'anti-choice',
#    'state',
#    'is;',
#    'report',
#    '2013',
#    'said',
#    'louisiana',
#    'worst',
#    'state',
#    'women.'],
#   'Negative'),
#  (['pulling', 'trump', 'like', '"minions"', 'candidates'], 'Positive'),
#  (['states',
#    'closed',
#    'background',
#    'check',
#    'loophole,',
#    'police',
#    'shooting',
#    'deaths',
#    'gun',
#    'suicides',
#    'cut',
#    'almost',
#    'half'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['enough...going', 'bed'], 'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['winner',
#    'american',
#    'capitalism',
#    '-fox',
#    'news',
#    'ratings',
#    '&amp;',
#    'brewers',
#    'beer',
#    'drunk',
#    'entertaining'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['huck.'], 'Positive'),
#  (['talk', 'god', 'today', 'tomorrow', 'war'], 'Negative'),
#  (['trump',
#    'literally',
#    'said',
#    'donates',
#    'politicians',
#    'calls',
#    'later',
#    'get',
#    'wants.',
#    'literally',
#    'said',
#    'that.…'],
#   'Negative'),
#  (['sorry', 'get', 'political', 'makes', 'sick.'], 'Negative'),
#  (['lindsay', 'graham', 'clue', 'american', 'people', 'anymore.'], 'Negative'),
#  (['excellent.', "can't", 'take', 'heat', 'get', 'kitchen.', 'bravo'],
#   'Positive'),
#  (['hey',
#    'ronald',
#    'reagan',
#    'relationship',
#    'assholes,',
#    'pardoned',
#    'millions',
#    'mexican',
#    'americans'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['dear', 'donald', 'trump,', 'sniff', 'couple', 'times,', 'head', 'ass'],
#   'Negative'),
#  (['funny',
#    'twitter',
#    'last',
#    'night',
#    'fucking',
#    'scary',
#    'one',
#    'half',
#    'selection,',
#    'potus!'],
#   'Negative'),
#  (['better', 'watch', 'believe', 'fighting', 'back.'], 'Positive'),
#  (['may',
#    'missed',
#    'it,',
#    'dissapointed',
#    'lack',
#    'conversation',
#    'marijuana.'],
#   'Negative'),
#  (['fox',
#    'presidential',
#    'candidates:',
#    'lets',
#    'talk',
#    'god',
#    'second.',
#    'founding',
#    'fathers:',
#    'jesus:'],
#   'Negative'),
#  (["what's",
#    'difference',
#    'moderators',
#    'cookie',
#    'monster?',
#    'cookie',
#    'monster',
#    'arm'],
#   'Negative'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"-mike',
#    'huckabee'],
#   'Negative'),
#  (['sydtrvp:',
#    'berniesanders:',
#    'tom',
#    'hanks.',
#    'finally.',
#    'somebody',
#    'makes',
#    'sense.'],
#   'Positive'),
#  (['need',
#    'order',
#    'another',
#    'green',
#    'apple',
#    'martini',
#    'process',
#    'hell',
#    'happened.'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['one',
#    'shocked',
#    'party',
#    'whose',
#    'audience',
#    'booed',
#    'american',
#    'soldier',
#    'applauded',
#    'rallying',
#    'cry',
#    'meaner',
#    'people.'],
#   'Negative'),
#  (['gave',
#    'time',
#    'god',
#    'race',
#    'relations.',
#    'know',
#    'take',
#    'candidates',
#    'seriously'],
#   'Negative'),
#  (["i'm", 'really', 'really', 'really', 'pissed', 'fox', 'news'], 'Negative'),
#  (['evidence', 'hacks', 'talk', 'comes', 'syria'], 'Negative'),
#  (["i'm",
#    'trying',
#    'watch',
#    'morning.',
#    'trying,',
#    'mean',
#    "i'm",
#    'gouging',
#    'eyeballs',
#    'steak',
#    'knife.'],
#   'Negative'),
#  (['always',
#    'support',
#    'everything',
#    'megyn',
#    'kelly',
#    'says,',
#    'tonight',
#    'hero.'],
#   'Positive'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['woman',
#    '&amp;',
#    'offended',
#    'needs',
#    'say',
#    'women',
#    'rather',
#    'sensitive',
#    'liberal',
#    'women!'],
#   'Negative'),
#  (['jobs',
#    'numbers',
#    'contrasts',
#    'dystopian',
#    'view',
#    'america',
#    'also',
#    'nostalgic',
#    'america',
#    'roads',
#    'paved',
#    'gold',
#    'never',
#    'existed'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['freedom', 'free...and', 'must', 'fight', 'everyday--@realbencarson'],
#   'Negative'),
#  (['ronald',
#    'raven',
#    'character',
#    'created',
#    'gop',
#    'influence',
#    'children.',
#    'sidekick',
#    'klu',
#    'klux',
#    'klam.'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['yes',
#    'goyim,',
#    'communist',
#    'sympathizer',
#    'approves',
#    'plz',
#    'stop',
#    'racist',
#    'htt…'],
#   'Negative'),
#  (['ate',
#    'lunch',
#    'last',
#    'nite.',
#    'get',
#    'compassion',
#    'moderation',
#    'without',
#    'bush',
#    'name.'],
#   'Positive'),
#  (['glad',
#    'see',
#    'jesus',
#    'got',
#    'shout-out',
#    'las',
#    "night's",
#    'debate.',
#    'candidates',
#    'pushing',
#    'envelope.'],
#   'Positive'),
#  (['lived', 'florida', 'years', 'jeb', 'bush', 'swear,', 'more...'],
#   'Negative'),
#  (['need',
#    'order',
#    'another',
#    'green',
#    'apple',
#    'martini',
#    'process',
#    'hell',
#    'happened.'],
#   'Negative'),
#  (['ben', 'carson,', 'solidifying', 'black', 'vote.'], 'Positive'),
#  (['done', 'last', 'nights', 'showed', 'true', 'colors', 'shined!'],
#   'Positive'),
#  (['vote', 'republican', '(god', 'forbid)', 'would', 'vote.'], 'Positive'),
#  (['chris',
#    'christie',
#    'want',
#    'increase',
#    'military',
#    'troops?',
#    'gop',
#    'congress',
#    'vote',
#    'veterans...'],
#   'Negative'),
#  (['success', 'debunks', 'liberal', 'debate:'], 'Negative'),
#  (['wwahammy:',
#    'jrehling:',
#    'donald',
#    'trump',
#    'says',
#    'time',
#    'political',
#    'correctness.'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['kasich', 'making', 'better', 'showing', 'far', 'thought', 'would'],
#   'Positive'),
#  (['bottom',
#    'line:',
#    'fox',
#    'news',
#    'lost',
#    'debate.',
#    'candidates',
#    'integrity.'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['paul:',
#    'want',
#    'collect',
#    'records',
#    'terrorists,',
#    'less',
#    '...',
#    'innocent',
#    'americans."',
#    'perfect',
#    'information'],
#   'Negative'),
#  (['want',
#    'finish',
#    'trump,',
#    'feed',
#    'troll.',
#    'fox',
#    'news',
#    'fed',
#    'troll',
#    'five-course',
#    'banquet.'],
#   'Negative'),
#  (["i've",
#    'heard',
#    'clearer',
#    'messages',
#    'charades',
#    'portion',
#    'hollywood',
#    'game',
#    'night.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['rubio',
#    'blamed',
#    'dodd-frank',
#    'wiping',
#    'banks.',
#    'chronology',
#    'disease',
#    'memento,',
#    'guys.'],
#   'Negative'),
#  (['"but', 'wanna', 'eat', 'vegetables"'], 'Negative'),
#  (['coincidence', 'watch', 'unless', 'cable.'], 'Negative'),
#  (['need', 'take', 'control', 'debate,', 'it,'], 'Positive'),
#  (['hate',
#    'call',
#    'social',
#    'security',
#    'entitlement.',
#    'government',
#    'fund',
#    'social',
#    'security',
#    'employer…'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['dispelled',
#    'fact',
#    'objective',
#    'moderator.',
#    'love',
#    'show,',
#    'moderating,',
#    'much…'],
#   'Negative'),
#  (['honestly,',
#    'donald',
#    'trump',
#    'types',
#    'petty',
#    'last',
#    "night's",
#    '--&gt;'],
#   'Negative'),
#  (['polling', 'high!', 'got', 'it👉🏾liars✔️'], 'Negative'),
#  (['carson',
#    'getting',
#    'zingers',
#    'end.',
#    'riding',
#    'all,',
#    "i'll",
#    'give',
#    'credit',
#    'medical',
#    'trailblazer.…'],
#   'Positive'),
#  (['need', 'grow', 'thicker', 'skin,', 'moderator', 'problem.'], 'Negative'),
#  (['huckabee...what!?!?!?#gopdebates'], 'Negative'),
#  (['chris', 'wallace.', 'need', 'one', 'horseman...'], 'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['whole',
#    'debacle',
#    'insult',
#    'every',
#    'american',
#    'common',
#    'sense',
#    'idea',
#    'history......#gopdebate'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Negative'),
#  (['john',
#    'gambling',
#    'right.',
#    "'debate'",
#    'group',
#    'interview',
#    'controlled',
#    'moderators',
#    'get',
#    'time',
#    'stage.'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['.@johnkasich',
#    'talks',
#    'common',
#    'sense,',
#    'repeatedly',
#    'voted',
#    'abortion',
#    'ban',
#    'would',
#    'make',
#    'doctors',
#    'criminals.'],
#   'Negative'),
#  (['candidates',
#    'mention',
#    'veteran',
#    'issues',
#    'besides',
#    'firing',
#    'personal.',
#    'veteran',
#    'homelessness',
#    'america',
#    'disgrace'],
#   'Negative'),
#  (['yes', 'even', 'nice', 'try', 'lib!'], 'Negative'),
#  (['dummies', 'lead', 'circle', 'jerk!'], 'Negative'),
#  (['head',
#    'republican',
#    'party',
#    'recently',
#    'said',
#    'party',
#    'longer',
#    'win',
#    'national',
#    'election.',
#    'tonight’s',
#    'confi…'],
#   'Negative'),
#  (['never', 'forget:', 'ted', 'cruz', 'never', 'supported', 'amnesty.'],
#   'Negative'),
#  (['questions', 'climate', 'change', 'voting', 'rights', 'make', 'showing'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['dr.', 'king', 'says', 'dream', 'became', 'nightmare...'], 'Negative'),
#  (['happiest', 'person', 'america', 'today', 'watching', 'debates', 'hrc.'],
#   'Positive'),
#  (['remember,', 'kids.', '"smart"', 'brother.'], 'Negative'),
#  (['think',
#    "i've",
#    'ever',
#    'seen',
#    'bunch',
#    'dudes',
#    'afraid',
#    'one',
#    'woman',
#    'last',
#    "night's",
#    'debates.'],
#   'Negative'),
#  (['shocking', 'twist', 'debate,', 'trump', 'brags', 'much', 'money'],
#   'Negative'),
#  (['hate',
#    'unions.',
#    'made',
#    'clear',
#    'respect,',
#    'even',
#    'teachers',
#    'union.'],
#   'Negative'),
#  (['get',
#    'wrong,',
#    'ben',
#    'carson',
#    'brilliant',
#    'man,',
#    'admire',
#    'him,',
#    'see',
#    'president,',
#    'true',
#    'lot…'],
#   'Negative'),
#  (['&amp;', 'impressed', 'w/her', 'last', 'pm.', 'took', 'entire', 'night!'],
#   'Positive'),
#  (['honestly',
#    "can't",
#    'stand',
#    'seeing',
#    'christie',
#    'feed/news',
#    'etc',
#    'worst',
#    'thing',
#    'say',
#    'abt',
#    "he's",
#    'fat?',
#    'educate'],
#   'Negative'),
#  (['16%', 'united', 'states', 'homes', 'sets', 'tuned', 'wow.'], 'Positive'),
#  (['asked', 'black', 'lives', 'mattered?!?'], 'Negative'),
#  (['scott',
#    'walker',
#    'continues',
#    'nod',
#    'agreement',
#    'candidates',
#    'praying',
#    'get',
#    'called',
#    'again.'],
#   'Negative'),
#  (['hey', 'rand,', 'say', 'negotiate', 'one', 'time'], 'Negative'),
#  (['call', 'bush', 'interview?'], 'Negative'),
#  (["'hangover'", 'today.', 'much', 'consumed...brain', 'fried.'], 'Negative'),
#  (['hey', 'american', 'citizenship', 'universal', 'human', 'right.'],
#   'Negative'),
#  (['gop', 'candidates', 'still', 'beating', 'chests', 'losing.#gopdebates'],
#   'Negative'),
#  (['listen',
#    'closely,all',
#    'repub.',
#    'candidates',
#    'talking',
#    'nonsense',
#    'trump.',
#    '.@nytimeskrugman:'],
#   'Negative'),
#  (['saw',
#    'political',
#    'science',
#    'teacher',
#    'news',
#    'talking',
#    'college',
#    'cool.'],
#   'Positive'),
#  (['democrat',
#    'announces,',
#    'join',
#    'republicans',
#    'making',
#    'easier',
#    'iran',
#    'get',
#    'nucl…'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['everyone',
#    'stream',
#    'watching',
#    'show,',
#    'mean',
#    'fox',
#    'going',
#    'cancel',
#    'soon.'],
#   'Negative'),
#  (['official;',
#    "gop's",
#    'frankenstein',
#    'monster',
#    '&amp;they',
#    'cannot',
#    'control'],
#   'Negative'),
#  (['know',
#    'finish',
#    'really',
#    'good',
#    'book',
#    'wake',
#    'next',
#    'day',
#    'wishing',
#    'wacky',
#    'adventures',
#    'would',
#    'never',
#    'end?',
#    '...the'],
#   'Positive'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['keep',
#    'focusing',
#    'shit',
#    'like',
#    'dumbfucks,',
#    '4th',
#    'wave',
#    'fascism',
#    'basic',
#    'bitches',
#    'anyway.'],
#   'Negative'),
#  (['meghan',
#    'kelly',
#    'awful',
#    'last',
#    'night.',
#    'getting',
#    'big',
#    'ego',
#    'annoying.'],
#   'Negative'),
#  (['fix',
#    'get-go.first',
#    'off,',
#    'question',
#    'pledging',
#    'support',
#    'addressed',
#    'directly'],
#   'Negative'),
#  (['alissalyn14:',
#    'nylonmag:',
#    'insane,',
#    'ridiculous',
#    'quotes',
#    'last',
#    "night's",
#    'seriously,'],
#   'Negative'),
#  (['ben',
#    'carson',
#    'also',
#    'want',
#    'follow',
#    "god's",
#    'law',
#    'non-virgin',
#    'wives',
#    'stoning',
#    'front',
#    "father's",
#    'house?'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (["what's",
#    'thoughts',
#    'comments',
#    'facebook',
#    'page',
#    'concerning',
#    'motive',
#    'behind'],
#   'Negative'),
#  (['thought',
#    'watching',
#    'political',
#    'function,',
#    'feel',
#    'like',
#    "i've",
#    'church.',
#    'good',
#    'way.'],
#   'Negative'),
#  (['number',
#    'aides',
#    'convicted',
#    'felonies',
#    'higher',
#    'number',
#    'voter',
#    'impersonation',
#    'cases',
#    'past',
#    'yrs'],
#   'Negative'),
#  (['cancel',
#    'primaries.',
#    'fox',
#    'party',
#    'set',
#    '&amp;',
#    'anointed',
#    'man',
#    'jeb',
#    'bush'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['impressed', 'three', 'fox', 'moderators', 'handled', 'debate.'],
#   'Negative'),
#  (['showed',
#    'quite',
#    'plainly',
#    'prepared',
#    'men',
#    '(+1',
#    'woman)',
#    'lead',
#    'nation.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['loved',
#    'carly',
#    'fiorina',
#    'said',
#    'one',
#    'first',
#    'two',
#    'phones',
#    'would',
#    'bibi',
#    'israel.'],
#   'Positive'),
#  (['audience', 'loves', 'carson'], 'Positive'),
#  (['today',
#    'time',
#    'next',
#    'president',
#    'one',
#    'year',
#    'office',
#    'empty',
#    'arena.'],
#   'Negative'),
#  (['tonight',
#    'learned',
#    'thinks',
#    'remove',
#    'civil',
#    'rights',
#    'fight',
#    'terrorism.'],
#   'Negative'),
#  (['cruz,', 'take', 'eos', 'previous', 'administrations', 'illegal!'],
#   'Positive'),
#  (['love',
#    'holds',
#    'highest',
#    'position',
#    'media',
#    'figure',
#    'fox',
#    'asking',
#    'questions',
#    'repub',
#    'war'],
#   'Positive'),
#  (['hugged', 'obama', 'deserve', 'stage', 'tonight.'], 'Negative'),
#  (['trump', 'person', 'performance', 'art?', 'serious', 'question.'],
#   'Negative'),
#  (['seem',
#    'even',
#    'candidates',
#    'praised',
#    '"sticking',
#    'question"',
#    'still',
#    'kind',
#    'run',
#    'around',
#    'it?'],
#   'Negative'),
#  (['someone', 'send'], 'Negative'),
#  (['stop', 'saying', 'affordable', 'healthcare', 'act,', 'damn'], 'Negative'),
#  (['many', 'great', 'jokes', 'twitter', 'tonight', 'many', 'stage.'],
#   'Negative'),
#  (['😂😂😂😂', 'drink!!!'], 'Negative'),
#  (['trump',
#    'said',
#    'country',
#    'needs',
#    'brain,',
#    'basically',
#    'saying',
#    'vote',
#    'him?'],
#   'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['exactly'], 'Negative'),
#  (['headed', 'presidential', 'debates.', 'ted!!'], 'Positive'),
#  (["i'm", 'republican', 'gotdam', 'love', 'chris', 'christie'], 'Positive'),
#  (['face',
#    'time',
#    'course.',
#    'running',
#    'something?she',
#    'needs',
#    "to.she's",
#    'journalist'],
#   'Negative'),
#  (['trump', 'divisive.', 'want', 'win', 'too!', 'get', 'there.'], 'Negative'),
#  (['dear',
#    'marco',
#    'rubio,',
#    'shut',
#    'fuck',
#    'up,',
#    'neither',
#    'entertaining',
#    'wise.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['dear',
#    'gov',
#    'walker,',
#    'nothing',
#    'brag',
#    'about,',
#    'fucked',
#    'state',
#    'wisconsin',
#    'suck',
#    'koch...'],
#   'Negative'),
#  (['watched',
#    'honestly',
#    'say',
#    'would',
#    'vote',
#    'rock',
#    'would',
#    'vote',
#    'democrat.',
#    'so…'],
#   'Negative'),
#  (['one',
#    'word',
#    'candidates',
#    'income',
#    'inequality,',
#    'climate',
#    'change,',
#    'citizens',
#    'united',
#    'student',
#    'debt.'],
#   'Negative'),
#  (['proved', 'ready', 'qualified'], 'Negative'),
#  (['jeb',
#    'stands',
#    '"act',
#    'love";',
#    'comments',
#    'earned',
#    'legal',
#    'status',
#    '[boo]'],
#   'Negative'),
#  (['best',
#    'statement',
#    'night',
#    'carson!',
#    'thank',
#    'putting',
#    'perspective',
#    'ignorant',
#    'world'],
#   'Positive'),
#  (['scary', 'touch', 'real', 'world', 'republicans', 'are.'], 'Negative'),
#  (['watching', 'the...'], 'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['imagined', 'performed', 'last', "night's"], 'Negative'),
#  (['trans',
#    'soldiers',
#    'die',
#    'huckabee',
#    "can't",
#    'foot',
#    'bill',
#    'make',
#    'fulfilled',
#    'human',
#    'beings?',
#    'really?'],
#   'Negative'),
#  (['someone', 'send'], 'Negative'),
#  (['worst', 'episode', 'fox', '&amp;', 'friends', 'ever.'], 'Negative'),
#  (['enough', 'win', 'center!:)', "he's", 'fantastic!'], 'Positive'),
#  (['really?',
#    'woman',
#    'supports',
#    'people',
#    'would',
#    '(dad?)',
#    'hung',
#    'streets'],
#   'Negative'),
#  (['would', 'dodge', 'giving', 'megyn', 'kelly', 'earful'], 'Positive'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['oh…',
#    'understand',
#    'now.',
#    'movie',
#    '“idiocracy”',
#    'actually',
#    'documentary.'],
#   'Negative'),
#  (['nice',
#    'work',
#    'asking',
#    'tough',
#    "q's",
#    'speaking',
#    'young',
#    "rep's,",
#    'hearts!'],
#   'Positive'),
#  (['boy:',
#    '"social',
#    'issues"',
#    'gop',
#    'code',
#    'control',
#    "women's",
#    'bodies',
#    '&amp;',
#    'sexuality',
#    'most.',
#    'hold',
#    'tight,',
#    'twitterland'],
#   'Negative'),
#  (['realization',
#    'dawns',
#    'us.',
#    '"holy',
#    'shit.',
#    "i've",
#    'watching',
#    'fox',
#    'news."'],
#   'Negative'),
#  (['1st',
#    'question',
#    'proof',
#    'himself.',
#    'spoiler',
#    'guaranteeing',
#    '4-8',
#    'years',
#    'hillary',
#    'hell.'],
#   'Negative'),
#  (['"i\'ll', 'best', 'that"'], 'Positive'),
#  (['dear', 'gop,', 'want', 'stop', 'abortions...'], 'Negative'),
#  (['man,',
#    "i'm",
#    'sorry,',
#    'nothing',
#    'w/politics,',
#    'totally',
#    'mediocre',
#    'here.'],
#   'Negative'),
#  (['congratulations',
#    'making',
#    '"presidential"',
#    'discussion.',
#    'knew',
#    'important?'],
#   'Negative'),
#  (["who's",
#    'real',
#    'illegal',
#    'alien',
#    'farrakhan',
#    'immigration',
#    '&amp;',
#    'mexican',
#    'bor...',
#    'via'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['hug?', 'thought', 'punched.', 'or,', 'guess', "that's", 'teachers.'],
#   'Negative'),
#  (['.@bencarson2016:', '"we', 'united', 'states', 'divided', 'states."'],
#   'Negative'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['great',
#    'reality',
#    'tv.',
#    "can't",
#    'wait',
#    'next',
#    'episode',
#    'see',
#    'gets',
#    'voted',
#    'island',
#    'dr.',
#    'moreau!'],
#   'Negative'),
#  (['yes,',
#    "obama's",
#    'dividing',
#    'country',
#    'creating',
#    'jobs,',
#    'ending',
#    'wars,',
#    'achieving',
#    'diplomacy',
#    'iran',
#    '&amp;',
#    'giving',
#    'people',
#    'healthca…'],
#   'Negative'),
#  (['thought', 'seen', 'all.'], 'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['retweet',
#    'tired',
#    'democrats',
#    'importing',
#    'third',
#    'world',
#    'peasants',
#    'win',
#    'elections,',
#    'gop',
#    'trying',
#    'st…'],
#   'Positive'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['respecting',
#    'women',
#    '"politically',
#    'correct",',
#    'complain',
#    'bullied',
#    'questioning?'],
#   'Negative'),
#  (['anger',
#    'bear',
#    'stayed',
#    'late',
#    'throwing',
#    'things',
#    'around',
#    'bedroom.',
#    'video',
#    'games',
#    'today.'],
#   'Negative'),
#  (['criticizing',
#    'performances',
#    'b/c',
#    'really',
#    'bad',
#    'job',
#    '"moderators."'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['embarrassment'], 'Negative'),
#  (['icymi:', 'no,', '"hell', 'no"'], 'Negative'),
#  (["kasich's",
#    'dad',
#    'mailman',
#    'hates',
#    'unions.',
#    'protected',
#    'letter',
#    'carriers',
#    'decades.'],
#   'Negative'),
#  (['shut', 'one', 'best', 'lines', 'debate', 'history'], 'Positive'),
#  (['even',
#    'though',
#    'super',
#    'conservative',
#    'reporter,',
#    'actually',
#    'like',
#    'megyn',
#    "kelly's",
#    'interview',
#    'style',
#    '&amp;',
#    'great'],
#   'Positive'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['demagogue', 'infuses', 'hate', "god's", 'name', 'christian.'], 'Negative'),
#  (['oppose', 'oppose', 'like,', 'how?'], 'Negative'),
#  (['fix', 'new', 'jersey', 'first'], 'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['paul:',
#    'want',
#    'collect',
#    'records',
#    'terrorists',
#    'fewer',
#    'americans."'],
#   'Negative'),
#  (['carson,',
#    'carson,',
#    'carson:',
#    'dammit',
#    'man!',
#    'say',
#    'words',
#    'racism',
#    'white',
#    'supremacy',
#    'audience!'],
#   'Negative'),
#  (['don’t',
#    'anyone',
#    'dare',
#    'vote',
#    'scott',
#    'walker.',
#    'would',
#    'rather',
#    'let',
#    'mother',
#    'die',
#    'concede',
#    'he’s',
#    'wrong',
#    'pregnan…'],
#   'Negative'),
#  (['commercials',
#    'fav',
#    'part',
#    'like',
#    'super',
#    'bowl',
#    'sunday',
#    'horrifying'],
#   'Negative'),
#  (['"trump', 'human', 'version', 'cankle"'], 'Negative'),
#  (['year-old', 'son', 'saw', 'said,', '"dad,', 'clown', 'tv!"'], 'Negative'),
#  (['pollster', 'called', 'told', 'won!', 'trump', 'go!'], 'Positive'),
#  (['"pimps', 'prostitues"', 'chug', 'wine', 'think', 'gonna', 'make'],
#   'Negative'),
#  (['hmmmm', 'tough', 'choice...'], 'Negative'),
#  (['gun',
#    'deaths',
#    'expected',
#    'surpass',
#    '33,000',
#    'year.',
#    'issue',
#    'raise:',
#    'gun',
#    'control.'],
#   'Negative'),
#  (['going.ronda',
#    'rousey',
#    'posterior',
#    'childish',
#    'comeback',
#    '"where',
#    'when?"',
#    'moment.#gopdebate'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['fox',
#    'presidential',
#    'candidates:',
#    'lets',
#    'talk',
#    'god',
#    'second.',
#    'founding',
#    'fathers:',
#    'jesus:'],
#   'Negative'),
#  (['big',
#    'problem',
#    'facing',
#    'democrats',
#    'get',
#    'hillary',
#    'sober',
#    'long',
#    'enough',
#    'debate?'],
#   'Negative'),
#  (['conservatives',
#    'drag',
#    'knocked',
#    'daughters',
#    'abortion',
#    '&amp;go',
#    'right',
#    'back',
#    'protesting',
#    'next'],
#   'Negative'),
#  (['yes,',
#    '"commercial',
#    'break"',
#    'time',
#    'wants',
#    'add',
#    'comment.',
#    'sick',
#    'bullshit.'],
#   'Negative'),
#  (["i'll",
#    'fight',
#    'u.s.',
#    'military',
#    'feared,',
#    'respected,',
#    '&amp;',
#    '⁰capable',
#    'fighting',
#    'force',
#    'world',
#    'ever',
#    'known'],
#   'Positive'),
#  (['sorry', 'offended', 'woman', 'offended', '!!!'], 'Negative'),
#  (['good',
#    'you,',
#    'megyn',
#    'kelly,',
#    'calling',
#    'ben',
#    'carson',
#    'idiot',
#    'right',
#    'bat.'],
#   'Negative'),
#  (['many',
#    'famous',
#    'people',
#    'petulantly',
#    'threatened',
#    'move',
#    'canada',
#    'one',
#    'debaters',
#    'won?'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Negative'),
#  (['dont', 'believe', 'facts', 'donald', 'trump', 'diss’', 'rican'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['.@frankluntz', 'analysis,', '"who', 'won?', '--&gt;'], 'Positive'),
#  (['good', 'john', 'kasich!'], 'Positive'),
#  (['fox',
#    '&amp;',
#    "executives'",
#    'attempt',
#    'kill',
#    "trump's",
#    'buzz/momentum',
#    'could',
#    'opposite',
#    'effect',
#    "'martyr",
#    "effect.'"],
#   'Negative'),
#  (['trump/carson', 'ticket', 'would', 'win', 'landslide...'], 'Positive'),
#  (['so,',
#    'trump',
#    'buys',
#    'politicians,',
#    'used',
#    'bankruptcy',
#    'advantage,',
#    'skirted',
#    'laws',
#    'money,',
#    'admitted',
#    'wanting',
#    'single',
#    'payer'],
#   'Negative'),
#  (['gotta', 'hand', 'him,', 'looks', 'well', 'hydrated', 'tonight.'],
#   'Positive'),
#  (['chris',
#    'christie',
#    'want',
#    'increase',
#    'military',
#    'troops?',
#    'gop',
#    'congress',
#    'vote',
#    'veterans...'],
#   'Negative'),
#  (['donald',
#    'trump',
#    'think',
#    'last',
#    'night',
#    'never',
#    'actually',
#    'answered',
#    'questions?'],
#   'Negative'),
#  (['jeb',
#    'stands',
#    '"act',
#    'love";',
#    'comments',
#    'earned',
#    'legal',
#    'status',
#    '[boo]'],
#   'Negative'),
#  (['congratulations', '&amp;', 'entire', 'hard', 'work', 'last', "night's"],
#   'Positive'),
#  (['case', 'missed', 'last', 'night', "here's", 'quick', 'recap'], 'Negative'),
#  (['support', 'amazing', 'father.', 'proud'], 'Positive'),
#  (['caller',
#    'rush',
#    'limbaugh',
#    'show:"i',
#    'lost',
#    'respect',
#    'fox',
#    'news."'],
#   'Negative'),
#  (['great,', 'great', 'list', 'idea', 'localization', 'election', 'coverage:'],
#   'Positive'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['know', 'right', 'sally', 'kohn', 'agrees', 'her,', 'definitely', 'line!'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Negative'),
#  (['senator',
#    'cruz,',
#    'word',
#    'god?',
#    'spit',
#    'tequila.',
#    'damn',
#    'megyn',
#    'kelly,',
#    'expensive',
#    'kind.'],
#   'Negative'),
#  (["they're", 'talking', 'hilary', 'like', 'john', 'wick.', 'love', 'it.'],
#   'Positive'),
#  (['ask', 'trump', 'question', 'get:', 'squirrel!'], 'Negative'),
#  (['nyer',
#    'work',
#    'hard',
#    'replace',
#    'chuck',
#    'schumer',
#    'vote',
#    'iran',
#    'nuclear',
#    'deal'],
#   'Negative'),
#  (['kicking', 'watch', 'party'], 'Positive'),
#  (['only...18',
#    'months',
#    'now,',
#    'debris',
#    'crashed',
#    'republican',
#    'party',
#    'would',
#    'wash',
#    'beach',
#    'somewhere.'],
#   'Negative'),
#  (['news',
#    'fails',
#    'disclose',
#    'pro-walker',
#    'debate',
#    'analyst',
#    'walker',
#    'adviser',
#    'co-author'],
#   'Negative'),
#  (['"we', 'military', 'reason.', 'fuck', 'shit', 'up!!!"'], 'Negative'),
#  (['gotta', 'give', 'props.', 'saw', 'ambush', 'calling', 'it.', 'ht…'],
#   'Negative'),
#  (['cop', 'killing', 'movement.'], 'Negative'),
#  (['actually', 'agree', 'something.', 'said', 'hurt', 'concur.'], 'Positive'),
#  (['day',
#    'man',
#    'mean',
#    'everybody',
#    'complaining',
#    'everybody',
#    'mean',
#    'him.'],
#   'Negative'),
#  (['focus',
#    'group',
#    'actually',
#    'likes',
#    'donald',
#    '&lt;--',
#    'riding',
#    "trump's",
#    'coattails!!'],
#   'Negative'),
#  (['needsh', 'luck', 'irithsh?!'], 'Negative'),
#  (['props', 'great', 'questions.'], 'Positive'),
#  (['rainbow',
#    'wigs',
#    'fire.',
#    'floppy',
#    'shoes',
#    'thrown',
#    'asunder.',
#    'never',
#    'slow',
#    'gawk',
#    'car',
#    'wreck.',
#    'unless'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['dr.', 'carson', 'remark', 'half', 'brain,', 'best', 'line'], 'Positive'),
#  (['jindal',
#    'giving',
#    'excellent',
#    'planned',
#    'parenthood',
#    'answer',
#    'here.'],
#   'Positive'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['kelly:',
#    'really',
#    'want',
#    'get',
#    'question',
#    'facebook."',
#    'yes.',
#    "that's",
#    'problem.'],
#   'Negative'),
#  (['chris',
#    'christie',
#    'tried',
#    'wrap',
#    '9/11',
#    '(giuliani-style)',
#    'so,',
#    'lied,',
#    'twice.'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['nutshell...'], 'Negative'),
#  (['working',
#    'huge',
#    'social',
#    'data',
#    'story.',
#    'interesting',
#    'trends,',
#    'trump',
#    'tweeted-about',
#    'moment',
#    'last',
#    'night.'],
#   'Negative'),
#  (['someone', 'send'], 'Negative'),
#  (['telling', 'get', 'warrant', 'per', '4th', 'amendment.', 'golden.'],
#   'Positive'),
#  (['commentary', 'needed', 'last', "night's", 'ftw!'], 'Positive'),
#  (['total',
#    'theatre',
#    'fox',
#    'news',
#    'tonight,',
#    'basis',
#    'fact',
#    'all...',
#    'garbage.'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Negative'),
#  (['conservative',
#    'thinks',
#    'chris',
#    'christie',
#    'last',
#    'night,',
#    'need',
#    'leave',
#    'party',
#    'immediately.'],
#   'Negative'),
#  (['megyn', 'kelly', 'slutty', 'all!'], 'Negative'),
#  (['rand',
#    'paul',
#    'came',
#    'little',
#    'petty',
#    'man',
#    'napoleon',
#    'complex.',
#    'blah'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['rand', 'paul', 'went', 'riot', 'shield', 'holding', 'bruh?!'], 'Negative'),
#  (['slurped',
#    'hard',
#    'establishments',
#    'slurpy',
#    'got',
#    'brain',
#    'freeze.',
#    'offered',
#    'award'],
#   'Negative'),
#  (['funny',
#    'think',
#    'may',
#    'tap',
#    'now.',
#    'one',
#    'dudes',
#    'foreign',
#    'policy.…'],
#   'Negative'),
#  (['scott',
#    'walker',
#    'lies:',
#    'says',
#    'budget',
#    '$535m',
#    'surplus',
#    '(actually',
#    '$1.76b',
#    'deficit)'],
#   'Negative'),
#  (['donald,', 'spite', 'megyn', 'kelly,', 'debate,'], 'Positive'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['scott', 'walker,', 'email', 'controversy?'], 'Negative'),
#  (['sad', 'trump', 'get', 'answer', 'question'], 'Negative'),
#  (['view',
#    'buffoon',
#    'schoolyard',
#    'bully',
#    "can't",
#    'function',
#    'normal',
#    'society.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['excited', 'waiting', 'years!!'], 'Positive'),
#  (['hope', 'buzzfeed', 'comprehensive', 'roundup', 'read', 'act', 'like'],
#   'Negative'),
#  (['takeaway',
#    "they're",
#    'terrible,',
#    'hate',
#    'tell',
#    "that's",
#    'whole',
#    'night',
#    'life',
#    'never',
#    'get',
#    'back.'],
#   'Negative'),
#  (['carson,',
#    'carson,',
#    'carson:',
#    'dammit',
#    'man!',
#    'say',
#    'words',
#    'racism',
#    'white',
#    'supremacy',
#    'audience!'],
#   'Negative'),
#  (['mention', 'last', 'night.', 'busy', 'saying', 'nasty', 'things', '&amp;'],
#   'Negative'),
#  (['fairness', 'owns', 'phrase.#gopdebate'], 'Negative'),
#  (['american',
#    'people',
#    'truly',
#    'learned',
#    'nothing',
#    'irrelevant',
#    'questions',
#    'asked',
#    'moderators.#fail'],
#   'Negative'),
#  (['illuminati', 'want', 'out,', 'win'], 'Positive'),
#  (['donald',
#    'trump:',
#    'reagan',
#    'con',
#    'man',
#    "'deliver",
#    "goods'",
#    'thinkprogress'],
#   'Negative'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things."',
#    'seems',
#    'like',
#    'would',
#    'really',
#    'insulting',
#    'those…'],
#   'Negative'),
#  (['none',
#    'made',
#    'trump',
#    'look',
#    'place',
#    'foolish',
#    'yet.',
#    'think',
#    'that.',
#    'done',
#    'crying,',
#    'think',
#    'agai…'],
#   'Negative'),
#  (['.@randpaul',
#    'reminds',
#    'evil',
#    'land',
#    'developer',
#    'trying',
#    'bulldoze',
#    'neighborhood',
#    'every',
#    '80s',
#    'movie',
#    'ever.'],
#   'Negative'),
#  (['image', 'best', 'sums', 'thoughts', 'regarding', 'last', "night's"],
#   'Negative'),
#  (['“@megynkelly:', 'live', 'reaction', 'attack', 'obvious', 'so…'],
#   'Positive'),
#  (['best',
#    'put',
#    'theater',
#    'substance',
#    'worst',
#    'acted',
#    'like',
#    'kingmakers.',
#    'little',
#    'substance',
#    'much',
#    '"defend',
#    'this"'],
#   'Negative'),
#  (['need', 'take', 'control', 'debate,', 'it,'], 'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Negative'),
#  (['trump',
#    'said',
#    'true',
#    'gentleman',
#    '&amp;',
#    'started',
#    'violently',
#    '69ing.'],
#   'Negative'),
#  (['one',
#    'word',
#    'civil',
#    'rights',
#    'mentioned',
#    'slogan.',
#    'subject',
#    'police',
#    'brutality'],
#   'Negative'),
#  (['everything', 'says', 'lie.'], 'Negative'),
#  (["'god",
#    'blessed',
#    'rep',
#    'party',
#    'lot',
#    'great',
#    'candidates,',
#    'dem',
#    'party',
#    'cannot',
#    'even',
#    'find',
#    'one"'],
#   'Positive'),
#  (['problem',
#    '"politically',
#    'correct,"',
#    'many',
#    'americans',
#    'anti-intellectual',
#    'ignorant.'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['prediction:',
#    'donald',
#    'trump',
#    'goes',
#    'post',
#    'debate',
#    'polls.',
#    'looks',
#    'crazier',
#    'anyone',
#    'else',
#    'entertaining'],
#   'Positive'),
#  (['trump',
#    'says',
#    'one',
#    'hand',
#    'everyone',
#    'pc.',
#    'except',
#    'megan',
#    'kelly',
#    'hurt',
#    'feelings',
#    'might',
#    'nice',
#    'anymore.'],
#   'Negative'),
#  (['people',
#    'cannot',
#    'run',
#    'country.',
#    'literally',
#    'afraid',
#    'will.',
#    'cannot',
#    'happen.'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Negative'),
#  (['minutes', 'candidates', 'spoken', 'rights', 'fetuses', 'rights', 'women'],
#   'Negative'),
#  (['admitted',
#    'attended',
#    'sex',
#    'wedding.',
#    "that's",
#    'sound',
#    'shot',
#    'nomination',
#    'circling',
#    'drain.'],
#   'Negative'),
#  (['men',
#    'apart',
#    'secret',
#    'criminal',
#    "fam.that's",
#    'met',
#    'wife&amp;their',
#    'secret',
#    'affair',
#    'started'],
#   'Negative'),
#  (["i'm", 'really', 'really', 'really', 'pissed', 'fox', 'news'], 'Negative'),
#  (['"mr.trump,',
#    'called',
#    'women',
#    'fat',
#    'pigs,',
#    'dogs,',
#    'slobs,',
#    'disgusting',
#    'animals..."',
#    '"only',
#    'rosie',
#    'o\'donnell."',
#    '*laughter,',
#    'applause*'],
#   'Negative'),
#  (["i'm",
#    'disappointed',
#    'never',
#    'bothered',
#    'ask',
#    'candidates',
#    'believed',
#    'guy'],
#   'Negative'),
#  (['ritzy_jewels:',
#    'redstatejake:',
#    'hey',
#    'foxnews',
#    'keep',
#    'degenerate',
#    'dwstweets',
#    'far',
#    'away'],
#   'Negative'),
#  (['top',
#    '(in',
#    'order):',
#    'carson,',
#    'cruz,',
#    'huckabee,',
#    'rubio,',
#    'paul',
#    '🐘🇺🇸'],
#   'Positive'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['lourack1:',
#    'rollingstone:',
#    'fox',
#    'news',
#    'targeted',
#    'donald',
#    'trump',
#    'republicans',
#    'call',
#    'smug…'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['cruz:',
#    'hardball',
#    'trump:',
#    'smear',
#    'rubio:',
#    'hardball',
#    'bush:',
#    'favorite',
#    'color?'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['wow',
#    'running',
#    'blatantly',
#    'running',
#    'bigotry',
#    'war',
#    'torture',
#    'addressing',
#    'problems',
#    'home'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['.@govmikehuckabee', 'tell', 'truth', 'tonigh…'], 'Negative'),
#  (['still',
#    'recovering',
#    '"caddyshack"',
#    'amc',
#    'proportionate',
#    'response',
#    'plutocratic',
#    'bologna.'],
#   'Negative'),
#  (['something',
#    'completely',
#    'different:',
#    'gop',
#    'primary',
#    'debate.',
#    'doubt',
#    'fox',
#    'throws',
#    'heat',
#    'clowns.'],
#   'Negative'),
#  (['received',
#    'call',
#    'begging',
#    'watch',
#    '&amp;',
#    'judge',
#    'performance',
#    'put',
#    'in.'],
#   'Negative'),
#  (['huckabee.'], 'Negative'),
#  (['whatever', 'ailes', 'you..'], 'Negative'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Negative'),
#  (['less,', 'think', 'assholes', 'would', 'seem', 'really', 'coherent.'],
#   'Negative'),
#  (['"@supermanhotmale:',
#    'makes',
#    'realize',
#    'raise',
#    'standards',
#    'let',
#    'kids',
#    'listen',
#    'to."',
#    'agree',
#    'big',
#    'time!!!'],
#   'Negative'),
#  (["let's",
#    'clear.',
#    '"nerve"',
#    'donald',
#    'trump',
#    'hitting',
#    'white',
#    'supremacy.'],
#   'Negative'),
#  (['snapchat',
#    'jeb',
#    'says',
#    'people',
#    'way',
#    'better',
#    'hillary',
#    'bernie.',
#    'couldnt',
#    'help',
#    'laugh.'],
#   'Negative'),
#  (['donald', 'trump', 'got', 'things', 'wrong'], 'Negative'),
#  (['remember',
#    'stage',
#    'last',
#    'election.',
#    'seems',
#    'ridiculous',
#    'again..palin',
#    'involved',
#    'before.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['mean,', 'matter', 'questions', 'unfair?', 'bother', 'answering', 'anyway'],
#   'Negative'),
#  (['rare',
#    'view',
#    'behind',
#    'stage',
#    'behind',
#    'scene',
#    'look',
#    'candidates..'],
#   'Negative'),
#  (['boy:',
#    '"social',
#    'issues"',
#    'gop',
#    'code',
#    'control',
#    "women's",
#    'bodies',
#    '&amp;',
#    'sexuality',
#    'most.',
#    'hold',
#    'tight,',
#    'twitterland'],
#   'Negative'),
#  (['last', 'nights', 'debates', 'movie', 'popped', 'head', 'reason'],
#   'Negative'),
#  (['trump',
#    'one',
#    'brought',
#    'immigration',
#    'national',
#    'stage',
#    'sure',
#    'lets',
#    'makes',
#    'sense'],
#   'Positive'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['jeb',
#    'bush',
#    'continues',
#    'act',
#    'like',
#    'person',
#    'wandered',
#    'election',
#    'wants',
#    'part',
#    'of.'],
#   'Negative'),
#  (['dogs', 'meaningless', 'gaffes.', "we're", 'great', 'start.'], 'Negative'),
#  (['donald',
#    'trump:',
#    'never',
#    'gone',
#    'bankrupt...',
#    'really',
#    'donald?',
#    'really',
#    'donald?',
#    'fucking',
#    'liar...'],
#   'Negative'),
#  (['frankly',
#    'time',
#    'total',
#    'political',
#    'correctness"',
#    'watch',
#    'zingers'],
#   'Negative'),
#  (['absurd', 'statement', 'huckabee'], 'Negative'),
#  (['miss',
#    'days',
#    'conservatives',
#    'wanted',
#    'presidential',
#    'candidate',
#    'was,',
#    'know,',
#    'conservative...'],
#   'Negative'),
#  (['"i\'m',
#    'new',
#    'kind',
#    'republican',
#    'moving',
#    'party',
#    'forward!',
#    'women',
#    'control',
#    'bodies!"',
#    'republicans'],
#   'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['trump:',
#    'banks',
#    'babies.',
#    'killers.',
#    'hell',
#    'yes',
#    'got',
#    'away',
#    'bad',
#    'deals,',
#    'make',
#    'usa',
#    'scofflaw',
#    'too!'],
#   'Negative'),
#  (["who's",
#    '"marginalizing"',
#    'women',
#    'lingerie',
#    'model',
#    'glass',
#    'houses?'],
#   'Negative'),
#  (['people', 'cheering', 'trump', '"booray"'], 'Negative'),
#  (['canwe', 'trust', 'abuses', 'power', 'ordering', 'attack'], 'Negative'),
#  (['biggest', 'winners–and', 'losers', 'latins', 'think', 'gop', 'lost'],
#   'Negative'),
#  (['hope', 'watched', 'republicans', 'condemned', 'obama', 'blistering.'],
#   'Negative'),
#  (['big', 'night', 'america', 'alcohol', 'poisoning'], 'Negative'),
#  (['feels',
#    'like',
#    'fox',
#    'news',
#    'tried',
#    'cool',
#    'parents',
#    'let',
#    'kids',
#    'party',
#    '&amp;',
#    'house',
#    'fire.'],
#   'Negative'),
#  (['jeb:', 'father', 'was...oh', 'nevermind.', 'parenting', 'overrated.'],
#   'Negative'),
#  (['know',
#    'aprx',
#    '700',
#    'laws',
#    'governing',
#    "women's",
#    'bodies',
#    'one',
#    'governing',
#    "men's?",
#    'true.'],
#   'Negative'),
#  (['cruz', 'mass', 'appeal'], 'Negative'),
#  (['nowwww', 'decides', 'put', 'names', 'screen', "they're", 'speaking.'],
#   'Negative'),
#  (['honor',
#    'last',
#    "night's",
#    "i'd",
#    'like',
#    'add',
#    'exclamation',
#    'point',
#    'end',
#    'name,',
#    'maybe',
#    'get',
#    'put',
#    'jeb!',
#    'vanity',
#    'plate.'],
#   'Positive'),
#  (['offensive,',
#    'confusing,',
#    'hilarious,',
#    '&amp;',
#    'wild',
#    'moments',
#    'h/t'],
#   'Negative'),
#  (['"[trump]',
#    'integrity,',
#    'character,',
#    'principles,',
#    "he's",
#    'proud',
#    'it."',
#    'agreed'],
#   'Negative'),
#  (['.....',
#    'gets',
#    'nod,',
#    'stopped',
#    'general',
#    'election.',
#    'not,',
#    'hand',
#    'election',
#    'dems'],
#   'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['trump',
#    'got',
#    'right,',
#    'nobody',
#    'would',
#    'talk',
#    'immigration,',
#    'untill',
#    'brought',
#    'up.'],
#   'Positive'),
#  (['many', 'great', 'jokes', 'twitter', 'tonight', 'many', 'stage.'],
#   'Negative'),
#  (['really',
#    'need',
#    'make',
#    'largest',
#    'military',
#    'power',
#    'world',
#    'bigger?'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['hate',
#    'call',
#    'social',
#    'security',
#    'entitlement.',
#    'government',
#    'fund',
#    'social',
#    'security',
#    'employer…'],
#   'Negative'),
#  (['fox.', 'else?', 'sloth', 'network?'], 'Negative'),
#  (['re:',
#    'audience',
#    'cheer',
#    'trumps',
#    'insults:',
#    'anyone',
#    'takes',
#    'delight',
#    'hurting',
#    'others',
#    'needs',
#    'examine',
#    'state',
#    'soul.'],
#   'Negative'),
#  (['donald', 'trump', 'biff', 'back', 'future'], 'Negative'),
#  (['"the', 'alinsky', 'model,', 'takingadvantage', 'useful', 'idiots"'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
# ...
#    'doubt',
#    'i"ll',
#    'able',
#    'take',
#    'many',
#    'enough',
#    'popcorn',
#    'universe!',
#    'onto'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['iran', 'deal', 'benefits', 'who?'], 'Negative'),
#  (['fundamental', 'problem', 'gop', 'party'], 'Negative'),
#  (['hey', 'media', 'ignore', 'trump,', 'maybe', "he'll", 'away.', 'hint.'],
#   'Negative'),
#  (['or,', 'you’re', 'listening'], 'Negative'),
#  (['wish', 'mentioned'], 'Negative'),
#  (['time', 'wavering', 'way', 'towards', 'done', 'enough', 'damage'],
#   'Negative'),
#  (['believe', "i'm", 'getting', 'air...'], 'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['debates', 'raise', 'ratings', 'fox', 'news', 'afraid', 'trump', 'shows.'],
#   'Positive'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['winners',
#    'imo:',
#    'marco',
#    'rubio,',
#    'rand',
#    'paul,',
#    'john',
#    'kasich',
#    'carly',
#    'fiorina'],
#   'Positive'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Negative'),
#  (['.@carlyfiorina',
#    'laid',
#    '30,000',
#    'workers',
#    'outsourced',
#    'jobs',
#    'china.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['give',
#    'credit',
#    'bad-ass',
#    'questions,',
#    "let's",
#    'real:',
#    'pre-written',
#    'fox',
#    'frame',
#    'debate.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['one',
#    'favorite',
#    'things',
#    'many',
#    'candidates',
#    "i've",
#    'seen',
#    'person.',
#    'thanks',
#    '&amp;'],
#   'Positive'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['[helen',
#    'lovejoy',
#    'voice]',
#    'somebody',
#    'please',
#    'think',
#    'christians?'],
#   'Negative'),
#  (['headed', 'presidential', 'debates.', 'ted!!'], 'Positive'),
#  (['proves', 'gop', 'impressive', 'pile', 'shit', 'voters.'], 'Negative'),
#  (['sen.',
#    'perry',
#    'calls',
#    '"aviation',
#    'assets"',
#    '(means',
#    'spy',
#    'drones)',
#    '"identify',
#    'individuals',
#    'doing"',
#    '24/7'],
#   'Negative'),
#  (['gun', 'violence', 'costs', 'americans', '$229b', 'annually'], 'Negative'),
#  (['fox',
#    'news',
#    'declared',
#    'megyn',
#    'kelly,',
#    'bret',
#    'baier,',
#    'chris',
#    'wallace',
#    "tonight's",
#    'debate.'],
#   'Negative'),
#  (['thing',
#    'watched',
#    'way',
#    "they'd",
#    'watch',
#    'trashy',
#    'reality',
#    'show',
#    "-that's",
#    'big',
#    'problem'],
#   'Negative'),
#  (['mk:',
#    '"mr.',
#    'simpson,',
#    'stalked',
#    'savagely',
#    'murdered',
#    'women.."',
#    'o.j.:',
#    '"only',
#    'ex-wife."',
#    '*audience',
#    'roars',
#    'laughter,',
#    'appl…'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['think',
#    'calling',
#    'bimbo,',
#    '&amp;',
#    'generally',
#    'denigrating',
#    'her,',
#    'proved',
#    'concern',
#    'misogyny…'],
#   'Negative'),
#  (['years',
#    'later,',
#    'doctors',
#    'tell',
#    'donald',
#    'trump',
#    'people',
#    'call',
#    'mentally',
#    'retarded.'],
#   'Negative'),
#  (['huckabee:',
#    'paying',
#    'transgender',
#    'surgery',
#    'soldiers,',
#    'sailors',
#    'airmen',
#    'make',
#    'country',
#    'safer'],
#   'Negative'),
#  (['according',
#    'huckabee',
#    'trans',
#    'people',
#    'experiments.',
#    '21st',
#    'century',
#    'lgbt',
#    'rights',
#    'thing.'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['evidence', 'hacks', 'talk', 'comes', 'syria'], 'Positive'),
#  (['one', 'question', 'climate', 'change', 'environment.'], 'Negative'),
#  (['look,', 'dad', 'poor', 'piece', 'shit.', 'so,', 'know,', 'get', 'it.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['insult',
#    'everyone',
#    '&amp;',
#    'call',
#    'stupid',
#    'cries',
#    'tough',
#    'fair',
#    'questions.#gopdebate'],
#   'Positive'),
#  (['unfathomable', 'would', 'ask', 'wasserman-schultz', 'postmortem'],
#   'Negative'),
#  (['today',
#    'time',
#    'next',
#    'president',
#    'one',
#    'year',
#    'office',
#    'empty',
#    'arena.'],
#   'Negative'),
#  (['fuck', 'dr.', "dre's", 'new', 'album', 'out!!!!'], 'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['likes',
#    'socialized',
#    'med',
#    'paying',
#    'corrupt',
#    'politicians.',
#    'conservatives',
#    'like',
#    'him,',
#    'why?#gopdebate'],
#   'Negative'),
#  (['think', 'fancies', 'kingmaker.'], 'Negative'),
#  (['"we\'ve', 'got', 'unite', 'country', 'stronger', 'united"'], 'Positive'),
#  (['breaking:',
#    'brian',
#    'williams',
#    'handed',
#    'chris',
#    'christie',
#    'donut',
#    'calm',
#    'down.'],
#   'Negative'),
#  (["can't", 'make', 'shit.'], 'Negative'),
#  (["kasich's",
#    'answer',
#    'gay',
#    'marriage',
#    'reasonable',
#    'someone',
#    'dislikes',
#    'it.'],
#   'Positive'),
#  (['fox',
#    'news',
#    'trying',
#    'convince',
#    'young',
#    'black',
#    'americans',
#    'worried',
#    'isis',
#    'police',
#    'terrorism'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Negative'),
#  (['surprisingly',
#    'impressed',
#    'last',
#    'night.',
#    'definitely',
#    'moving',
#    'list',
#    'candidates!'],
#   'Positive'),
#  (['bushs...', 'fuck', 'jeb'], 'Negative'),
#  (['hey', 'look', 'feelings', 'donald', 'trump', 'summed', 'one', 'gif'],
#   'Negative'),
#  (['guys,',
#    'separation',
#    'church',
#    'state',
#    'also',
#    'constitution.#gopdebates'],
#   'Negative'),
#  (["i'm", 'getting', 'fiorina', 'yard', 'signs!'], 'Positive'),
#  (["i'm", 'watching', 'says', 'thinking', 'years.', 'time', 'for…'],
#   'Positive'),
#  (['.@realdonaldtrump',
#    'retweets',
#    'twitter',
#    'users',
#    'calling',
#    '"bimbo"',
#    '"unbecoming"'],
#   'Negative'),
#  (['took',
#    'advantage',
#    'law,',
#    'everyone',
#    'else.',
#    'deserve',
#    'president.',
#    'not.'],
#   'Negative'),
#  (['chris',
#    'christie',
#    'wants',
#    '"collect',
#    'records',
#    'terrorists".',
#    'may',
#    'suggest?'],
#   'Negative'),
#  (['trump',
#    'said,',
#    '"megyn,',
#    'ask',
#    'nine',
#    'candidates,',
#    'plan',
#    'support',
#    'win',
#    'nomination."'],
#   'Negative'),
#  (['says', 'economic', 'growth', 'extend', 'lower', 'class?', 'really?'],
#   'Negative'),
#  (['carly!', 'matthews', 'asshat!!', 'nice', 'job!'], 'Negative'),
#  (['watched', 'piece', 'shit'], 'Negative'),
#  (['scott',
#    'walker:',
#    '"everywhere',
#    'hillary',
#    'touched',
#    'messed',
#    'up"',
#    'ironic',
#    'scott',
#    'walker',
#    'messed',
#    'state',
#    'wisconsin.'],
#   'Negative'),
#  (['cop', 'killing', 'movement.'], 'Negative'),
#  (['lol!', 'watching', 'like...'], 'Negative'),
#  (['yes', 'ridiculous', 'that.'], 'Negative'),
#  (['anyone',
#    'keeping',
#    'track',
#    'many',
#    'times',
#    'lincoln',
#    'rolls',
#    'grave',
#    'tonight?'],
#   'Negative'),
#  (['pretty', 'pissed', 'missed'], 'Negative'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"-mike',
#    'huckabee'],
#   'Negative'),
#  (['marc', 'rubio', 'put', 'college', 'application', 'next', 'year.'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['huckabee', 'travesty.'], 'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['hey',
#    'jeb',
#    'push',
#    'keystone?',
#    'gonna',
#    'popular',
#    'fracking',
#    'states.'],
#   'Negative'),
#  (['trump',
#    'fine',
#    'spectacular,',
#    'good',
#    'enough.',
#    'post-debate',
#    "he's",
#    'killing',
#    'himself.'],
#   'Negative'),
#  (['republican',
#    'audience',
#    'loudly',
#    'cheering',
#    'inhumanity,',
#    'warmongering,',
#    'lies',
#    'racism',
#    'wild',
#    'abandon.',
#    'yeah,',
#    'nothing',
#    'new.'],
#   'Negative'),
#  (['biggest',
#    'made',
#    'last',
#    'night',
#    'staying',
#    'social',
#    'media.',
#    'feel',
#    'much',
#    'smarter',
#    'happier',
#    'morning'],
#   'Positive'),
#  (['big',
#    'man',
#    'child',
#    'donald',
#    'trump',
#    'mad',
#    'megyn',
#    'kelly',
#    'calling',
#    'garbage.'],
#   'Negative'),
#  (['sometimes',
#    'like',
#    'character,',
#    "he's",
#    'still',
#    'candidate',
#    'calling',
#    'like',
#    'is.'],
#   'Positive'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['misogyny',
#    'surprise',
#    'considering',
#    'men',
#    'stage,',
#    'pontificating',
#    'bodies'],
#   'Negative'),
#  (['question',
#    'candidates:',
#    'think',
#    'people',
#    'working',
#    '40+',
#    'hrs',
#    'week',
#    'live',
#    'poverty?',
#    'ht…'],
#   'Negative'),
#  (['carson,', 'rubio,', 'fiorina,', '&amp;', 'cruz', 'night.'], 'Positive'),
#  (['america', '2015', 'deserve', 'ben', 'carson', 'via'], 'Negative'),
#  (['"my',
#    'record',
#    'clear.',
#    'hate',
#    'women',
#    'want',
#    'affordable',
#    'birth',
#    'control',
#    'std',
#    'screenings."'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['lame', 'question', 'trump...', 'megan', 'kelly'], 'Negative'),
#  (['donald',
#    'trump',
#    'wants',
#    'build',
#    'great',
#    'wall',
#    'china',
#    '(in',
#    'america).',
#    'fully',
#    'equipped',
#    'door.'],
#   'Negative'),
#  (['conservative',
#    "media's",
#    'influence',
#    '"they',
#    'give',
#    'damn',
#    'governing"'],
#   'Negative'),
#  (['nutshell', 'via', 'vote', 'true', 'blue', '2016'], 'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['ben',
#    'govt',
#    'fraud',
#    'shows',
#    'african',
#    'american',
#    'kids',
#    'exponentially',
#    'risk',
#    'mmr'],
#   'Negative'),
#  (["i'm",
#    'still',
#    'reminds',
#    'jimmy',
#    'carter',
#    'bit',
#    'like',
#    'fine,',
#    'need',
#    'tuffer'],
#   'Positive'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (["i'm", 'missing', 'comedy', 'year.'], 'Negative'),
#  (['trump',
#    'said,',
#    '"megyn,',
#    'ask',
#    'nine',
#    'candidates,',
#    'plan',
#    'support',
#    'win',
#    'nomination."'],
#   'Positive'),
#  (["who's",
#    'real',
#    'illegal',
#    'alien',
#    'farrakhan',
#    'immigration',
#    '&amp;',
#    'mexican',
#    'bor...',
#    'via'],
#   'Negative'),
#  (['watching',
#    'seems',
#    'like',
#    'bashing',
#    'pbo',
#    '"failed',
#    'policies"',
#    'impo…'],
#   'Negative'),
#  (['john', 'kasich', 'ready', 'lead.', 'join', 'team,', 'claire!:'],
#   'Positive'),
#  (['fox',
#    'trump:',
#    'financial',
#    'practices',
#    'shitty',
#    'mess.',
#    'differ',
#    'potus?',
#    'trump:',
#    'won’t.',
#    'people',
#    'too.'],
#   'Negative'),
#  (['tonight',
#    'learned',
#    'thinks',
#    'remove',
#    'civil',
#    'rights',
#    'fight',
#    'terrorism.'],
#   'Negative'),
#  (['morning',
#    'joe',
#    'crowd',
#    'giving',
#    'fiorina',
#    'false',
#    'sense',
#    'intelligence.',
#    'sarah',
#    'palin',
#    'lighter',
#    'hair'],
#   'Negative'),
#  (['would', 'say', 'trump', 'appeared', 'incompetent', 'nice.'], 'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['trump', 'trumped!'], 'Negative'),
#  (['every',
#    'time',
#    'bell',
#    'rings',
#    'rand',
#    "paul's",
#    'little',
#    'poodle',
#    'ears',
#    'keep',
#    'perking',
#    'up.'],
#   'Negative'),
#  (['one',
#    'clown',
#    'stage',
#    'idiots',
#    'last',
#    'night,',
#    'match',
#    "pbo's",
#    'accomplishments'],
#   'Negative'),
#  (['perhaps', "they'll", 'talk', 'racism', "they're", 'asked', 'god', 'told'],
#   'Negative'),
#  (['gotta', 'love'], 'Positive'),
#  (['planned',
#    'parenthood',
#    'performing',
#    'half',
#    'birth',
#    'abortions,',
#    'immoral,',
#    'unconstitutional,',
#    'unethical'],
#   'Negative'),
#  (['god', 'question', 'end?!', 'god!'], 'Negative'),
#  (['candidate',
#    'comes',
#    'says',
#    'winner',
#    'member',
#    'party,',
#    "that's",
#    'good.',
#    'happened.'],
#   'Negative'),
#  (['scott',
#    'walker',
#    'forces',
#    'women',
#    'carry',
#    'rapists’',
#    'pregnancies',
#    '&amp;',
#    'let',
#    'men',
#    'sue',
#    'abortion'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['cancel',
#    'primaries.',
#    'fox',
#    'party',
#    'set',
#    '&amp;',
#    'anointed',
#    'man',
#    'jeb',
#    'bush'],
#   'Negative'),
#  (['two', 'great', 'debates!', 'favorites?', 'let', 'know', 'thoughts'],
#   'Positive'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['million',
#    'people',
#    'watched',
#    'fox',
#    'last',
#    'nite',
#    '&amp;',
#    "there's",
#    'million',
#    'people',
#    'tuned',
#    'right',
#    'find',
#    'thought',
#    'it..-rush'],
#   'Negative'),
#  (['camille',
#    'paglia',
#    'trying',
#    'spike',
#    'saying',
#    'kasich',
#    'won,',
#    'simply',
#    'liberal',
#    'bias',
#    'talking?',
#    'lol'],
#   'Negative'),
#  (['big',
#    'problem',
#    'facing',
#    'democrats',
#    'get',
#    'hillary',
#    'sober',
#    'long',
#    'enough',
#    'debate?'],
#   'Negative'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Negative'),
#  (['comes', 'it,', 'way', 'many', 'turds', 'punch', 'bowl', 'last', 'night.'],
#   'Negative'),
#  (['bitch', 'betta', 'social', 'security', 'money.'], 'Negative'),
#  (['jonathanfarrel7:',
#    'jonathanfarrel7:',
#    'luciabrawley:',
#    'christian',
#    'litmus',
#    'test?',
#    "let's",
#    'refer',
#    'constitution,',
#    'shall',
#    'we?'],
#   'Negative'),
#  (['faves', 'really', 'well', 'last', 'night:', 'rubio-kasich', 'ticket!'],
#   'Positive'),
#  (["let's",
#    'forget',
#    'one',
#    'ever',
#    'shot',
#    '"not',
#    'politically',
#    'correct"',
#    'one',
#    'liberties',
#    'violated',
#    'over…'],
#   'Negative'),
#  (["can't",
#    'gal',
#    'enjoy',
#    'watching',
#    'without',
#    '"tolerant"',
#    'people',
#    'attacking',
#    'nowhere?',
#    'rrright,',
#    'b/c',
#    "that's",
#    'cool...👎👎'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['trump',
#    'simply',
#    "can't",
#    'harmed',
#    'impolitik',
#    'statements.',
#    'like',
#    'trying',
#    'drown',
#    'aquaman.'],
#   'Negative'),
#  (['foxnews',
#    'one',
#    'goal',
#    '&amp;',
#    'one',
#    'goal',
#    'only:',
#    'profit.',
#    'american',
#    'tragedy',
#    'is:',
#    'one',
#    'whole',
#    'political',
#    'party',
#    'guinea',
#    'pig'],
#   'Negative'),
#  (['unfathomable', 'would', 'ask', 'wasserman-schultz', 'postmortem'],
#   'Negative'),
#  (['so,', 'tweet', 'way', 'funny.'], 'Negative'),
#  (['carson’s',
#    'goal',
#    'tonight:',
#    'introduce',
#    'america,',
#    'make',
#    'people',
#    'remember',
#    'him.',
#    'think',
#    'accomplished',
#    'that.'],
#   'Positive'),
#  (['could',
#    'stand',
#    'learn',
#    'lot',
#    'format.',
#    'bbc',
#    'much',
#    'better',
#    'job',
#    'fox',
#    'news'],
#   'Negative'),
#  (['know',
#    'last',
#    'night',
#    'horribly',
#    'run',
#    'liberals/cnn',
#    'say',
#    'well',
#    'organized.'],
#   'Negative'),
#  (['candidate',
#    'received',
#    'word',
#    'god?!',
#    'presidential',
#    'hopefuls?!',
#    'america?!',
#    'christian',
#    'brotherhood',
#    'america'],
#   'Negative'),
#  (['ask',
#    'rubio',
#    'gang',
#    'ocho',
#    'hear',
#    'anything',
#    'talking',
#    'points',
#    'marco.'],
#   'Negative'),
#  (['moderator:',
#    '"@scottwalker,when',
#    "'rip",
#    'iran',
#    'deal',
#    'day',
#    "1',what",
#    'then?"',
#    'walker:',
#    'remember',
#    'tying',
#    'yellow',
#    'ribbons',
#    'trees."'],
#   'Negative'),
#  ...]

# %%
wordcloud_draw(train_pos)

# %%
testdata1={'feature':['Hi how are you','How are you doing']}
testdata1=pd.DataFrame(testdata1)
wordcloud_draw(testdata1['feature'])
# Out:
# Hi how are you How are you doing

# %%
for row in train.iterrows():
    print(row)
# Out:
# (6342, text         RT @BrewStuds: Disappointed that #Trump didn't...
# sentiment                                             Negative
# Name: 6342, dtype: object)
# (312, text         #JebBush was so thoughtful in #GOPdebate - #re...
# sentiment                                             Positive
# Name: 312, dtype: object)
# (4504, text         #GOPDebate Americans are FED UP with the LIES!...
# sentiment                                             Negative
# Name: 4504, dtype: object)
# (8950, text         RT @SupermanHotMale: I lived here in Florida f...
# sentiment                                             Negative
# Name: 8950, dtype: object)
# (10227, text         How embarrassing. The whole world is watching ...
# sentiment                                             Negative
# Name: 10227, dtype: object)
# (5559, text         RT @FreedomJames7: Chris Christie Is A Loser.\...
# sentiment                                             Negative
# Name: 5559, dtype: object)
# (6627, text         RT @paulisci: Comparing #macdebate to #GOPdeba...
# sentiment                                             Negative
# Name: 6627, dtype: object)
# (13144, text         @FoxNews address #PlannedParenthood and the bu...
# sentiment                                             Negative
# Name: 13144, dtype: object)
# (12828, text         RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# sentiment                                             Negative
# Name: 12828, dtype: object)
# (1369, text         RT @rolandsmartin: SHAME ON Brett Baier, Chris...
# sentiment                                             Negative
# Name: 1369, dtype: object)
# (2083, text         RT @PJHughes12: @FoxNews debate moderators wer...
# sentiment                                             Negative
# Name: 2083, dtype: object)
# (3243, text         RT @bamasevere: Megyn Kelly shouldn't be worri...
# sentiment                                             Negative
# Name: 3243, dtype: object)
# (11329, text         RT @SalMasekela: Is Kasich aware that he's mak...
# sentiment                                             Positive
# Name: 11329, dtype: object)
# (2097, text         RT @KennyW_NLR: @michellemalkin \n\n@FoxNews s...
# sentiment                                             Negative
# Name: 2097, dtype: object)
# (6686, text         Donated to @PPact in @JebBush name during the ...
# sentiment                                             Positive
# Name: 6686, dtype: object)
# (4214, text         RT @SooperMexican: quit trying to make Kasich ...
# sentiment                                             Negative
# Name: 4214, dtype: object)
# (6503, text         #Trump's truest and best line: "if it weren’t ...
# sentiment                                             Positive
# Name: 6503, dtype: object)
# (7397, text         Nothing about the #GOPDebate really matters. I...
# sentiment                                             Negative
# Name: 7397, dtype: object)
# (10649, text         If you want to defend life, Cruz, make sure no...
# sentiment                                             Negative
# Name: 10649, dtype: object)
# (9835, text         RT @monaeltahawy: Seriously: GOP voters think ...
# sentiment                                             Negative
# Name: 9835, dtype: object)
# (11432, text         RT @RWSurferGirl: FOX News won't admit who the...
# sentiment                                             Positive
# Name: 11432, dtype: object)
# (6869, text         RT @coryhaik: .@washingtonpost collab w @Geniu...
# sentiment                                             Positive
# Name: 6869, dtype: object)
# (1401, text         RT @Mamadoxie: YES @rushlimbaugh. We're waitin...
# sentiment                                             Negative
# Name: 1401, dtype: object)
# (10230, text         I thought maybe @LILBTHEBASEDGOD was going to ...
# sentiment                                             Negative
# Name: 10230, dtype: object)
# (9860, text         Lol, fun! Aghhh I'm pumped! This is a nerds fa...
# sentiment                                             Positive
# Name: 9860, dtype: object)
# (3790, text         When did the path to becoming President become...
# sentiment                                             Negative
# Name: 3790, dtype: object)
# (11473, text         RT @goldietaylor: Huckabee. #GOPDebates http:/...
# sentiment                                             Negative
# Name: 11473, dtype: object)
# (909, text         RT @jphoganorg: After #GOPDebate #FeelTheBern ...
# sentiment                                             Positive
# Name: 909, dtype: object)
# (12604, text         Huckabee looks like one of those Muppets up in...
# sentiment                                             Negative
# Name: 12604, dtype: object)
# (10497, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 10497, dtype: object)
# (6850, text         RT @CounselorAdrian: #BerkeleyBreathed came ba...
# sentiment                                             Negative
# Name: 6850, dtype: object)
# (11577, text         RT @SupermanHotMale: Dear John Kasich, Beat yo...
# sentiment                                             Positive
# Name: 11577, dtype: object)
# (7265, text         RT @kevinrfree: Please stop talking about Rona...
# sentiment                                             Negative
# Name: 7265, dtype: object)
# (10113, text         RT @ShawnDrurySC: Jeb: My father was...OH NEVE...
# sentiment                                             Negative
# Name: 10113, dtype: object)
# (1203, text         RT @OhNoSheTwitnt: Probably the funniest thing...
# sentiment                                             Negative
# Name: 1203, dtype: object)
# (5112, text         Just as we get the world we deserve, the #GOP ...
# sentiment                                             Negative
# Name: 5112, dtype: object)
# (5595, text         RT @KennedyNation: #Rubio repeal #DoddFrank. A...
# sentiment                                             Positive
# Name: 5595, dtype: object)
# (2811, text         #GOPDebate @tedcruz is it really worth mention...
# sentiment                                             Negative
# Name: 2811, dtype: object)
# (5134, text         RT @scorpio5053: @WalterWhfla @DesignerDeb3 @r...
# sentiment                                             Negative
# Name: 5134, dtype: object)
# (10509, text         RT @SalMasekela: Senator Cruz, any word from G...
# sentiment                                             Negative
# Name: 10509, dtype: object)
# (1225, text         RT @NARAL: .@BobbyJindal brags about how anti-...
# sentiment                                             Negative
# Name: 1225, dtype: object)
# (5682, text         RT @zigzagoonsquad: Pulling for trump he is li...
# sentiment                                             Positive
# Name: 5682, dtype: object)
# (1556, text         RT @shannonrwatts: In states that closed backg...
# sentiment                                             Negative
# Name: 1556, dtype: object)
# (8756, text         RT @RWSurferGirl: So @megynkelly posed for adu...
# sentiment                                             Negative
# Name: 8756, dtype: object)
# (10835, text         Had enough...going to bed #GOPDebates http://t...
# sentiment                                             Negative
# Name: 10835, dtype: object)
# (11293, text         RT @RWSurferGirl: Is it just me or does anyone...
# sentiment                                             Negative
# Name: 11293, dtype: object)
# (4366, text         RT @ChrisSonge: Who was the winner - American ...
# sentiment                                             Negative
# Name: 4366, dtype: object)
# (12571, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 12571, dtype: object)
# (12763, text         RT @RWSurferGirl: Thanks Fox News, you're rais...
# sentiment                                             Positive
# Name: 12763, dtype: object)
# (13064, text         YOU GO HUCK. #GOPDebates #tcot
# sentiment                          Positive
# Name: 13064, dtype: object)
# (10380, text         They talk about God today tomorrow WAR #GOPDeb...
# sentiment                                             Negative
# Name: 10380, dtype: object)
# (413, text         RT @deray: Trump literally said that he donate...
# sentiment                                             Negative
# Name: 413, dtype: object)
# (6874, text         RT @LaceyLuken: Sorry to get political but thi...
# sentiment                                             Negative
# Name: 6874, dtype: object)
# (11905, text         Lindsay Graham doesn't have a clue who the Ame...
# sentiment                                             Negative
# Name: 11905, dtype: object)
# (4287, text         RT @JaniceDean: The @FoxNews #GOPdebate was ex...
# sentiment                                             Positive
# Name: 4287, dtype: object)
# (9051, text         RT @SupermanHotMale: Hey #GopDebates, Ronald R...
# sentiment                                             Negative
# Name: 9051, dtype: object)
# (11488, text         Is it just me or does anyone else want to punc...
# sentiment                                             Negative
# Name: 11488, dtype: object)
# (11315, text         RT @SupermanHotMale: Dear Donald Trump, sniff ...
# sentiment                                             Negative
# Name: 11315, dtype: object)
# (2850, text         As funny as Twitter was last night during the ...
# sentiment                                             Negative
# Name: 2850, dtype: object)
# (3242, text         #GOPDebate  @FoxNews better watch out I believ...
# sentiment                                             Positive
# Name: 3242, dtype: object)
# (5685, text         I may have missed it, but I was dissapointed w...
# sentiment                                             Negative
# Name: 5685, dtype: object)
# (10158, text         RT @Just_JDreaming: Fox to Presidential Candid...
# sentiment                                             Negative
# Name: 10158, dtype: object)
# (6987, text         RT @ShaaaaaNaNa: what's the difference between...
# sentiment                                             Negative
# Name: 6987, dtype: object)
# (10418, text         RT @jamiaw: "The purpose of the military is to...
# sentiment                                             Negative
# Name: 10418, dtype: object)
# (4100, text         sydtrvp: RT BernieSanders: Tom Hanks. Finally....
# sentiment                                             Positive
# Name: 4100, dtype: object)
# (9408, text         RT @RWSurferGirl: I need to order another gree...
# sentiment                                             Negative
# Name: 9408, dtype: object)
# (10544, text         RT @RWSurferGirl: It is very disappointing tha...
# sentiment                                             Negative
# Name: 10544, dtype: object)
# (1619, text         I for one am shocked that the party whose audi...
# sentiment                                             Negative
# Name: 1619, dtype: object)
# (3751, text         RT @kayski: They gave more time to God than th...
# sentiment                                             Negative
# Name: 3751, dtype: object)
# (9083, text         RT @RWSurferGirl: I'm really really really pis...
# sentiment                                             Negative
# Name: 9083, dtype: object)
# (9123, text         RT @Lukewearechange: where is this evidence th...
# sentiment                                             Negative
# Name: 9123, dtype: object)
# (4398, text         I'm trying to watch the #GOPDebate this mornin...
# sentiment                                             Negative
# Name: 4398, dtype: object)
# (2486, text         RT @feministabulous: I don't always support ev...
# sentiment                                             Positive
# Name: 2486, dtype: object)
# (8595, text         RT @RWSurferGirl: We the American people pick ...
# sentiment                                             Negative
# Name: 8595, dtype: object)
# (5842, text         RT @MistiTweets: I Am A Woman &amp; Not Offend...
# sentiment                                             Negative
# Name: 5842, dtype: object)
# (5730, text         Jobs numbers contrasts with dystopian view of ...
# sentiment                                             Negative
# Name: 5730, dtype: object)
# (9730, text         RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# sentiment                                             Negative
# Name: 9730, dtype: object)
# (8239, text         RT @olakunlesoriyan: FREEDOM is NOT FREE...and...
# sentiment                                             Negative
# Name: 8239, dtype: object)
# (7392, text         Ronald Raven is a character created by the GOP...
# sentiment                                             Negative
# Name: 7392, dtype: object)
# (12119, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 12119, dtype: object)
# (2566, text         RT @ThaRightStuff: Yes goyim, communist sympat...
# sentiment                                             Negative
# Name: 2566, dtype: object)
# (2708, text         @JohnKasich ate @JebBush's lunch last nite. Yo...
# sentiment                                             Positive
# Name: 2708, dtype: object)
# (7075, text         Glad to see that Jesus got a shout-out at las ...
# sentiment                                             Positive
# Name: 7075, dtype: object)
# (9405, text         RT @SupermanHotMale: I lived here in Florida f...
# sentiment                                             Negative
# Name: 9405, dtype: object)
# (8358, text         RT @RWSurferGirl: I need to order another gree...
# sentiment                                             Negative
# Name: 8358, dtype: object)
# (10374, text         Ben Carson, solidifying the black vote. #GOPDe...
# sentiment                                             Positive
# Name: 10374, dtype: object)
# (777, text         RT @JaxT0520: Done with @FoxNews after last ni...
# sentiment                                             Positive
# Name: 777, dtype: object)
# (9493, text         If I had to vote Republican (God forbid) #John...
# sentiment                                             Positive
# Name: 9493, dtype: object)
# (9413, text         RT @jsc1835: Chris Christie - You want to incr...
# sentiment                                             Negative
# Name: 9413, dtype: object)
# (6873, text         #asian Success Debunks Liberal #WhitePrivilege...
# sentiment                                             Negative
# Name: 6873, dtype: object)
# (4096, text         wwahammy: RT JRehling: #GOPDebate Donald Trump...
# sentiment                                             Negative
# Name: 4096, dtype: object)
# (9162, text         RT @RWSurferGirl: We the American people pick ...
# sentiment                                             Negative
# Name: 9162, dtype: object)
# (796, text         Kasich making a better showing so far than I t...
# sentiment                                             Positive
# Name: 796, dtype: object)
# (1599, text         RT @RWSurferGirl: Bottom Line:\n\nFox News los...
# sentiment                                             Negative
# Name: 1599, dtype: object)
# (9849, text         RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# sentiment                                             Negative
# Name: 9849, dtype: object)
# (2879, text         RT @anna_strophe: Paul: "I want to collect mor...
# sentiment                                             Negative
# Name: 2879, dtype: object)
# (1955, text         RT @benshapiro: If you want to finish Trump, y...
# sentiment                                             Negative
# Name: 1955, dtype: object)
# (5171, text         RT @BrianBalthazar: I've heard clearer message...
# sentiment                                             Negative
# Name: 5171, dtype: object)
# (13700, text         RT @RWSurferGirl: I think Cruz and Trump need ...
# sentiment                                             Positive
# Name: 13700, dtype: object)
# (5572, text         RT @ReformedBroker: Rubio just blamed Dodd-Fra...
# sentiment                                             Negative
# Name: 5572, dtype: object)
# (4556, text         RT @CJsucitymvp: "but i don't wanna eat my veg...
# sentiment                                             Negative
# Name: 4556, dtype: object)
# (520, text         It's not a coincidence that you couldn't watch...
# sentiment                                             Negative
# Name: 520, dtype: object)
# (12350, text         @tedcruz and @realDonaldTrump need to take con...
# sentiment                                             Positive
# Name: 12350, dtype: object)
# (11677, text         RT @racquetball54: I hate when they call Socia...
# sentiment                                             Negative
# Name: 11677, dtype: object)
# (12131, text         RT @RWSurferGirl: Why doesn't Chris Wallace as...
# sentiment                                             Negative
# Name: 12131, dtype: object)
# (11262, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 11262, dtype: object)
# (4576, text         RT @kwfelsher: @theblaze @megynkelly dispelled...
# sentiment                                             Negative
# Name: 4576, dtype: object)
# (2791, text         Honestly, Donald Trump you were ALL types of p...
# sentiment                                             Negative
# Name: 2791, dtype: object)
# (2961, text         RT @peddoc63: This is why @realDonaldTrump is ...
# sentiment                                             Negative
# Name: 2961, dtype: object)
# (9854, text         RT @jamiaw: Carson getting in some zingers at ...
# sentiment                                             Positive
# Name: 9854, dtype: object)
# (3968, text         @realDonaldTrump need to grow some thicker ski...
# sentiment                                             Negative
# Name: 3968, dtype: object)
# (10370, text         Oh Huckabee...what!?!?!?#GOPDebates
# sentiment                               Negative
# Name: 10370, dtype: object)
# (4590, text         RT @DadusAmericanis: @realDonaldTrump @FrankLu...
# sentiment                                             Negative
# Name: 4590, dtype: object)
# (12240, text         RT @RWSurferGirl: The candidates don't have to...
# sentiment                                             Negative
# Name: 12240, dtype: object)
# (5924, text         This whole debacle is an insult to every Ameri...
# sentiment                                             Negative
# Name: 5924, dtype: object)
# (10527, text         RT @RWSurferGirl: It is very disappointing tha...
# sentiment                                             Negative
# Name: 10527, dtype: object)
# (13797, text         RT @ericstonestreet: Trump has Cam hands. #GOP...
# sentiment                                             Negative
# Name: 13797, dtype: object)
# (6984, text         John Gambling is right. #GOPDebate isn't a 'de...
# sentiment                                             Negative
# Name: 6984, dtype: object)
# (10378, text         RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# sentiment                                             Negative
# Name: 10378, dtype: object)
# (7768, text         RT @NARAL: .@JohnKasich talks about common sen...
# sentiment                                             Negative
# Name: 7768, dtype: object)
# (3392, text         How can the candidates not mention any veteran...
# sentiment                                             Negative
# Name: 3392, dtype: object)
# (10944, text         Yes he did @BernardGoldberg #GOPDebates. Not e...
# sentiment                                             Negative
# Name: 10944, dtype: object)
# (2734, text         #GOPDebate - They dummies couldn't lead a circ...
# sentiment                                             Negative
# Name: 2734, dtype: object)
# (4411, text         RT @sallykohn: The head of the Republican Part...
# sentiment                                             Negative
# Name: 4411, dtype: object)
# (3827, text         Never Forget: Ted Cruz Never Supported Amnesty...
# sentiment                                             Negative
# Name: 3827, dtype: object)
# (4749, text         Questions on climate change and voting rights ...
# sentiment                                             Negative
# Name: 4749, dtype: object)
# (13786, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 13786, dtype: object)
# (5455, text         Dr. King says his dream became a nightmare... ...
# sentiment                                             Negative
# Name: 5455, dtype: object)
# (7973, text         RT @fieldnegro: The happiest person in America...
# sentiment                                             Positive
# Name: 7973, dtype: object)
# (13517, text         RT @EnzoWestie: Remember, kids. #jebbush is th...
# sentiment                                             Negative
# Name: 13517, dtype: object)
# (2732, text         I don't think I've ever seen a bunch of dudes ...
# sentiment                                             Negative
# Name: 2732, dtype: object)
# (4488, text         RT @maddeclair: In a shocking twist during the...
# sentiment                                             Negative
# Name: 4488, dtype: object)
# (9348, text         #GOP2016 hate all unions. #GOPDebates made it ...
# sentiment                                             Negative
# Name: 9348, dtype: object)
# (2574, text         RT @JRpolitirants: Don't get me wrong, Ben Car...
# sentiment                                             Negative
# Name: 2574, dtype: object)
# (8188, text         @pondering_this @CarlyFiorina I had &amp; was ...
# sentiment                                             Positive
# Name: 8188, dtype: object)
# (5752, text         Honestly I can't stand seeing Christie on my f...
# sentiment                                             Negative
# Name: 5752, dtype: object)
# (989, text         RT @jjosephwilliams: 16% of United States home...
# sentiment                                             Positive
# Name: 989, dtype: object)
# (11678, text         @megynkelly just asked is black lives mattered...
# sentiment                                             Negative
# Name: 11678, dtype: object)
# (3515, text         RT @MattyIceAZ: Scott Walker continues to nod ...
# sentiment                                             Negative
# Name: 3515, dtype: object)
# (12098, text         Hey Rand, say negotiate one more time #GOPDebates
# sentiment                                             Negative
# Name: 12098, dtype: object)
# (12266, text         Why don't you just call this the Bush intervie...
# sentiment                                             Negative
# Name: 12266, dtype: object)
# (1606, text         Have a #GOPDebate 'hangover' today.  So much c...
# sentiment                                             Negative
# Name: 1606, dtype: object)
# (3083, text         RT @GayPatriot: Hey @JebBush - American citize...
# sentiment                                             Negative
# Name: 3083, dtype: object)
# (12244, text         GOP candidates still beating their chests over...
# sentiment                                             Negative
# Name: 12244, dtype: object)
# (2714, text         If you listen closely,all the Repub. candidate...
# sentiment                                             Negative
# Name: 2714, dtype: object)
# (4395, text         I just saw my political science teacher on the...
# sentiment                                             Positive
# Name: 4395, dtype: object)
# (6713, text         RT @TheMurdochTimes: Democrat #ChuckSchumer an...
# sentiment                                             Negative
# Name: 6713, dtype: object)
# (12436, text         RT @RWSurferGirl: Thanks Fox News, you're rais...
# sentiment                                             Positive
# Name: 12436, dtype: object)
# (12758, text         RT @tmetz1226: Everyone in my stream is watchi...
# sentiment                                             Negative
# Name: 12758, dtype: object)
# (3004, text         It's official; #Trump is GOP's Frankenstein 'a...
# sentiment                                             Negative
# Name: 3004, dtype: object)
# (5705, text         You know when you finish a really good book an...
# sentiment                                             Positive
# Name: 5705, dtype: object)
# (8553, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 8553, dtype: object)
# (5003, text         Keep focusing on shit like the #GOPDebate you ...
# sentiment                                             Negative
# Name: 5003, dtype: object)
# (4365, text         @FoxNews Meghan Kelly was awful last night. Sh...
# sentiment                                             Negative
# Name: 4365, dtype: object)
# (949, text         #gopdebate the fix was in from the get-go.Firs...
# sentiment                                             Negative
# Name: 949, dtype: object)
# (7820, text         AlissaLyn14: RT NylonMag: The 10 most insane, ...
# sentiment                                             Negative
# Name: 7820, dtype: object)
# (6558, text         RT @cenkuygur: Does Ben Carson also want to fo...
# sentiment                                             Negative
# Name: 6558, dtype: object)
# (13764, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 13764, dtype: object)
# (4030, text         @megynkelly #GOPDebate What's your thoughts on...
# sentiment                                             Negative
# Name: 4030, dtype: object)
# (1869, text         RT @iRreverin: Thought I was watching a politi...
# sentiment                                             Negative
# Name: 1869, dtype: object)
# (10872, text         RT @SpudLovr: #True Number of #Walker16 aides ...
# sentiment                                             Negative
# Name: 10872, dtype: object)
# (10002, text         Cancel the primaries. Fox Party set up &amp; a...
# sentiment                                             Negative
# Name: 10002, dtype: object)
# (9495, text         RT @RWSurferGirl: Is it just me or does anyone...
# sentiment                                             Negative
# Name: 9495, dtype: object)
# (10216, text         #GOPDebates Not very impressed how the three F...
# sentiment                                             Negative
# Name: 10216, dtype: object)
# (7892, text         RT @laprofe63: #WishfulThinking! #GOPDebate sh...
# sentiment                                             Negative
# Name: 7892, dtype: object)
# (10965, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 10965, dtype: object)
# (11225, text         Loved that Carly Fiorina said one of her first...
# sentiment                                             Positive
# Name: 11225, dtype: object)
# (2843, text         RT @KatiePavlich: Audience loves Carson #GOPDe...
# sentiment                                             Positive
# Name: 2843, dtype: object)
# (10662, text         RT @NickSylian: From today to the time the nex...
# sentiment                                             Negative
# Name: 10662, dtype: object)
# (8395, text         RT @RWSurferGirl: Tonight we learned that @Gov...
# sentiment                                             Negative
# Name: 8395, dtype: object)
# (10145, text         Cruz, go and take down other EOs in previous a...
# sentiment                                             Positive
# Name: 10145, dtype: object)
# (2711, text         RT @warriorwoman91: I love how @megynkelly who...
# sentiment                                             Positive
# Name: 2711, dtype: object)
# (11568, text         RT @RWSurferGirl: After @GovChristie hugged Ob...
# sentiment                                             Negative
# Name: 11568, dtype: object)
# (9354, text         RT @mbaratz: Is Trump a person or performance ...
# sentiment                                             Negative
# Name: 9354, dtype: object)
# (4723, text         Does it seem that even the candidates that are...
# sentiment                                             Negative
# Name: 4723, dtype: object)
# (9104, text         RT @monaeltahawy: Can someone send this to #GO...
# sentiment                                             Negative
# Name: 9104, dtype: object)
# (13062, text         And if they don't stop saying #ObamaCare. Affo...
# sentiment                                             Negative
# Name: 13062, dtype: object)
# (8859, text         RT @BettyFckinWhite: So many great jokes on Tw...
# sentiment                                             Negative
# Name: 8859, dtype: object)
# (11245, text         😂😂😂😂 Drink!!! #Trump #GOPDebates  https://t.co...
# sentiment                                             Negative
# Name: 11245, dtype: object)
# (5028, text         RT @Timcast: Trump said this country needs bra...
# sentiment                                             Negative
# Name: 5028, dtype: object)
# (12247, text         RT @RWSurferGirl: You would never know @realDo...
# sentiment                                             Negative
# Name: 12247, dtype: object)
# (2135, text         Exactly #GOPDebate http://t.co/XqjbInIZTE
# sentiment                                     Negative
# Name: 2135, dtype: object)
# (8263, text         RT @Lrihendry: #TedCruz headed into the Presid...
# sentiment                                             Positive
# Name: 8263, dtype: object)
# (7832, text         I'm not a republican but GOTDAM I love Chris C...
# sentiment                                             Positive
# Name: 7832, dtype: object)
# (7929, text         Who had the MOST face time in the #GOPDebates?...
# sentiment                                             Negative
# Name: 7929, dtype: object)
# (11847, text         @JebBush Trump is divisive. I want to win too!...
# sentiment                                             Negative
# Name: 11847, dtype: object)
# (12027, text         RT @SupermanHotMale: Dear Marco Rubio, just sh...
# sentiment                                             Negative
# Name: 12027, dtype: object)
# (10578, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 10578, dtype: object)
# (10303, text         RT @SupermanHotMale: Dear Gov Walker, you have...
# sentiment                                             Negative
# Name: 10303, dtype: object)
# (3990, text         RT @TheMorningSpew: Having watched the #GOPDeb...
# sentiment                                             Negative
# Name: 3990, dtype: object)
# (1540, text         RT @BRios82: Not one word by @GOP Candidates a...
# sentiment                                             Negative
# Name: 1540, dtype: object)
# (2797, text         RT @tweetybirdnerd: #RonPaul proved at the #GO...
# sentiment                                             Negative
# Name: 2797, dtype: object)
# (9383, text         RT @LindaSuhler: Jeb Stands By "Act of Love"; ...
# sentiment                                             Negative
# Name: 9383, dtype: object)
# (10239, text         @RealBenCarson @jamiaw Best Statement of the n...
# sentiment                                             Positive
# Name: 10239, dtype: object)
# (1302, text         it's scary how out of touch with the real worl...
# sentiment                                             Negative
# Name: 1302, dtype: object)
# (6282, text         RT @curlyheadRED: Me watching the... #GOPDebat...
# sentiment                                             Negative
# Name: 6282, dtype: object)
# (13576, text         RT @RWSurferGirl: I think Cruz and Trump need ...
# sentiment                                             Positive
# Name: 13576, dtype: object)
# (2539, text         How @realDonaldTrump imagined he performed at ...
# sentiment                                             Negative
# Name: 2539, dtype: object)
# (11033, text         So trans soldiers can die for you Huckabee but...
# sentiment                                             Negative
# Name: 11033, dtype: object)
# (10836, text         RT @monaeltahawy: Can someone send this to #GO...
# sentiment                                             Negative
# Name: 10836, dtype: object)
# (3457, text         RT @benshapiro: This is the worst episode of F...
# sentiment                                             Negative
# Name: 3457, dtype: object)
# (11594, text         It's enough to win center!:) he's fantastic! #...
# sentiment                                             Positive
# Name: 11594, dtype: object)
# (7181, text         @KimKardashian Really? The woman who supports ...
# sentiment                                             Negative
# Name: 7181, dtype: object)
# (2946, text         RT @eurorabbit: Only a #Cuckservative would do...
# sentiment                                             Positive
# Name: 2946, dtype: object)
# (10162, text         RT @RWSurferGirl: Why doesn't Chris Wallace as...
# sentiment                                             Negative
# Name: 10162, dtype: object)
# (1706, text         Oh… I understand now. The movie “Idiocracy” is...
# sentiment                                             Negative
# Name: 1706, dtype: object)
# (6501, text         Nice work @megynkelly asking tough q's in #GOP...
# sentiment                                             Positive
# Name: 6501, dtype: object)
# (12113, text         Oh boy: "social issues" = GOP code for who can...
# sentiment                                             Negative
# Name: 12113, dtype: object)
# (445, text         RT @kumailn: And now the realization dawns on ...
# sentiment                                             Negative
# Name: 445, dtype: object)
# (6160, text         1st question #GOPDebate should be proof @realD...
# sentiment                                             Negative
# Name: 6160, dtype: object)
# (10052, text         "I'll be my best to do that" #GOPDebates
# sentiment                                    Positive
# Name: 10052, dtype: object)
# (58, text         RT @mydaughtersarmy: Dear GOP,\nIf you want to...
# sentiment                                             Negative
# Name: 58, dtype: object)
# (13628, text         RT @MarkDavis: Man, I'm sorry, this has nothin...
# sentiment                                             Negative
# Name: 13628, dtype: object)
# (5349, text         Congratulations @Rosie for making the "preside...
# sentiment                                             Negative
# Name: 5349, dtype: object)
# (6081, text         @bbc_chirinos Who's the real illegal alien #GO...
# sentiment                                             Negative
# Name: 6081, dtype: object)
# (12731, text         RT @RWSurferGirl: I think Cruz and Trump need ...
# sentiment                                             Positive
# Name: 12731, dtype: object)
# (8422, text         RT @RWSurferGirl: So @megynkelly posed for adu...
# sentiment                                             Negative
# Name: 8422, dtype: object)
# (2707, text         RT @dawnintheworld: @ChrisChristie you HUG?  I...
# sentiment                                             Negative
# Name: 2707, dtype: object)
# (10327, text         .@BenCarson2016: "We are the United States not...
# sentiment                                             Negative
# Name: 10327, dtype: object)
# (9518, text         RT @RWSurferGirl: I'd really like to see how l...
# sentiment                                             Negative
# Name: 9518, dtype: object)
# (2638, text         #GOPDebate was great reality TV. Can't wait fo...
# sentiment                                             Negative
# Name: 2638, dtype: object)
# (1346, text         RT @BRios82: Yes, @JebBush Obama's dividing th...
# sentiment                                             Negative
# Name: 1346, dtype: object)
# (10972, text         @EODChick @GovMikeHuckabee I thought I had see...
# sentiment                                             Negative
# Name: 10972, dtype: object)
# (11815, text         RT @RWSurferGirl: Ask Trump a legitimate quest...
# sentiment                                             Positive
# Name: 11815, dtype: object)
# (7626, text         RT @Bidenshairplugs: Retweet if you're tired o...
# sentiment                                             Positive
# Name: 7626, dtype: object)
# (12376, text         RT @RWSurferGirl: You would never know @realDo...
# sentiment                                             Negative
# Name: 12376, dtype: object)
# (4302, text         Respecting women is  being "politically correc...
# sentiment                                             Negative
# Name: 4302, dtype: object)
# (4639, text         Anger Bear stayed up too late and was throwing...
# sentiment                                             Negative
# Name: 4639, dtype: object)
# (171, text         @megynkelly @BretBaier #ChrisWallace, #America...
# sentiment                                             Negative
# Name: 171, dtype: object)
# (10264, text         RT @RWSurferGirl: The candidates don't have to...
# sentiment                                             Negative
# Name: 10264, dtype: object)
# (10234, text         #RandPaul is an embarrassment #GOPDebates
# sentiment                                     Negative
# Name: 10234, dtype: object)
# (218, text         RT @GovernorPerry: ICYMI: Not just no, but "he...
# sentiment                                             Negative
# Name: 218, dtype: object)
# (13586, text         KASICH'S DAD WAS A MAILMAN BUT HE HATES UNIONS...
# sentiment                                             Negative
# Name: 13586, dtype: object)
# (5855, text         RT @CalebBonham: @RandPaul's shut down of @Chr...
# sentiment                                             Positive
# Name: 5855, dtype: object)
# (90, text         Even though she's a super conservative reporte...
# sentiment                                             Positive
# Name: 90, dtype: object)
# (11004, text         RT @RWSurferGirl: You would never know @realDo...
# sentiment                                             Negative
# Name: 11004, dtype: object)
# (12378, text         This demagogue infuses hate in God's name he i...
# sentiment                                             Negative
# Name: 12378, dtype: object)
# (7822, text         They oppose #PlannedParenthood and they oppose...
# sentiment                                             Negative
# Name: 7822, dtype: object)
# (10247, text         Fix New Jersey first @ChrisChristie #GOPDebates
# sentiment                                           Negative
# Name: 10247, dtype: object)
# (12457, text         RT @RWSurferGirl: Thanks Fox News, you're rais...
# sentiment                                             Positive
# Name: 12457, dtype: object)
# (13042, text         RT @Popehat: #GOPDebates Paul: "I want to coll...
# sentiment                                             Negative
# Name: 13042, dtype: object)
# (9890, text         RT @monaeltahawy: Carson, Carson, Carson: damm...
# sentiment                                             Negative
# Name: 9890, dtype: object)
# (4155, text         RT @savvyliterate: Don’t anyone dare vote for ...
# sentiment                                             Negative
# Name: 4155, dtype: object)
# (12303, text         The commercials are my fav part of #GOPDebates...
# sentiment                                             Negative
# Name: 12303, dtype: object)
# (12918, text         "Trump is the human version of a cankle" @TheR...
# sentiment                                             Negative
# Name: 12918, dtype: object)
# (3665, text         RT @cenkuygur: My 5 year-old son saw @realDona...
# sentiment                                             Negative
# Name: 3665, dtype: object)
# (9682, text         A pollster just called and I told them @realDo...
# sentiment                                             Positive
# Name: 9682, dtype: object)
# (12910, text         RT @averykayla: "Pimps are prostitues" I now h...
# sentiment                                             Negative
# Name: 12910, dtype: object)
# (6362, text         #GOPDebate Hmmmm tough choice... http://t.co/h...
# sentiment                                             Negative
# Name: 6362, dtype: object)
# (5787, text         gun deaths in the US are expected to surpass 3...
# sentiment                                             Negative
# Name: 5787, dtype: object)
# (2001, text         @megynkelly going.Ronda Rousey on @realDonaldT...
# sentiment                                             Negative
# Name: 2001, dtype: object)
# (12246, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 12246, dtype: object)
# (9385, text         RT @Just_JDreaming: Fox to Presidential Candid...
# sentiment                                             Negative
# Name: 9385, dtype: object)
# (7945, text         RT @RWSurferGirl: A big problem facing Democra...
# sentiment                                             Negative
# Name: 7945, dtype: object)
# (1446, text         RT @Maliheh_: @GrnEyedMandy Conservatives drag...
# sentiment                                             Negative
# Name: 1446, dtype: object)
# (2428, text         RT @IronHide_81: Oh yes, we have to go to a "c...
# sentiment                                             Negative
# Name: 2428, dtype: object)
# (1155, text         RT @GovMikeHuckabee: I'll fight for the U.S. m...
# sentiment                                             Positive
# Name: 1155, dtype: object)
# (9115, text         RT @TrotAlex: Sorry @edhenry I was not offende...
# sentiment                                             Negative
# Name: 9115, dtype: object)
# (2317, text         RT @billmaher: Good for you, Megyn Kelly, call...
# sentiment                                             Negative
# Name: 2317, dtype: object)
# (8755, text         RT @deancameron: How many famous people petula...
# sentiment                                             Negative
# Name: 8755, dtype: object)
# (13566, text         RT @RWSurferGirl: I think Cruz and Trump need ...
# sentiment                                             Negative
# Name: 13566, dtype: object)
# (10488, text         I DONT BELIEVE HIM AND THIS IS WHY ALL FACTS D...
# sentiment                                             Negative
# Name: 10488, dtype: object)
# (9218, text         RT @RWSurferGirl: We the American people pick ...
# sentiment                                             Negative
# Name: 9218, dtype: object)
# (12645, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 12645, dtype: object)
# (12285, text         RT @RWSurferGirl: Thanks Fox News, you're rais...
# sentiment                                             Positive
# Name: 12285, dtype: object)
# (1360, text         RT @GovMikeHuckabee: .@FrankLuntz #GOPDebate a...
# sentiment                                             Positive
# Name: 1360, dtype: object)
# (11740, text         Good for you John Kasich! #GOPDebates
# sentiment                                 Positive
# Name: 11740, dtype: object)
# (2739, text         Fox &amp; executives' attempt to kill Trump's ...
# sentiment                                             Negative
# Name: 2739, dtype: object)
# (1106, text         Trump/Carson ticket would win in a landslide.....
# sentiment                                             Positive
# Name: 1106, dtype: object)
# (9531, text         RT @Apathycase: So, Trump buys politicians, us...
# sentiment                                             Negative
# Name: 9531, dtype: object)
# (12843, text         I gotta hand it to him, @marcorubio looks very...
# sentiment                                             Positive
# Name: 12843, dtype: object)
# (9528, text         RT @jsc1835: Chris Christie - You want to incr...
# sentiment                                             Negative
# Name: 9528, dtype: object)
# (6310, text         How can Donald Trump think that he won the #GO...
# sentiment                                             Negative
# Name: 6310, dtype: object)
# (9521, text         RT @LindaSuhler: Jeb Stands By "Act of Love"; ...
# sentiment                                             Negative
# Name: 9521, dtype: object)
# (4405, text         RT @robportman: Congratulations to @ChairmanBo...
# sentiment                                             Positive
# Name: 4405, dtype: object)
# (7557, text         RT @Wolfofwarrenst: Just in case you missed th...
# sentiment                                             Negative
# Name: 7557, dtype: object)
# (4572, text         RT @IvankaTrump: At the #GOPdebate in support ...
# sentiment                                             Positive
# Name: 4572, dtype: object)
# (666, text         Caller on the Rush Limbaugh show:"I have lost ...
# sentiment                                             Negative
# Name: 666, dtype: object)
# (5217, text         Great, great list idea for localization of ele...
# sentiment                                             Positive
# Name: 5217, dtype: object)
# (10329, text         RT @RWSurferGirl: It is very disappointing tha...
# sentiment                                             Negative
# Name: 10329, dtype: object)
# (1525, text         Now I know I was right about #GOPDebate. If Sa...
# sentiment                                             Negative
# Name: 1525, dtype: object)
# (13547, text         RT @RWSurferGirl: I think Cruz and Trump need ...
# sentiment                                             Negative
# Name: 13547, dtype: object)
# (10628, text         RT @SalMasekela: Senator Cruz, any word from G...
# sentiment                                             Negative
# Name: 10628, dtype: object)
# (535, text         RT @pattonoswalt: They're talking about Hilary...
# sentiment                                             Positive
# Name: 535, dtype: object)
# (11382, text         Ask Trump Question you get: SQUIRREL! #GOPDebates
# sentiment                                             Negative
# Name: 11382, dtype: object)
# (1070, text         RT @OGOPer: This NYer will work hard to replac...
# sentiment                                             Negative
# Name: 1070, dtype: object)
# (9064, text         RT @MelissaFwu: Kicking off our #GOPDebates Wa...
# sentiment                                             Positive
# Name: 9064, dtype: object)
# (6646, text         If only...18 months from now, debris from a cr...
# sentiment                                             Negative
# Name: 6646, dtype: object)
# (3771, text         #Fox News Fails To Disclose Its Pro-Walker Deb...
# sentiment                                             Negative
# Name: 3771, dtype: object)
# (874, text         RT @kumailn: "We have the military for a reaso...
# sentiment                                             Negative
# Name: 874, dtype: object)
# (6600, text         RT @EvilConservativ: Gotta give @LindseyGraham...
# sentiment                                             Negative
# Name: 6600, dtype: object)
# (11457, text         @GeekNStereo: #BlackLivesMatter is a cop killi...
# sentiment                                             Negative
# Name: 11457, dtype: object)
# (398, text         I actually agree with @AndreaTantaros on somet...
# sentiment                                             Positive
# Name: 398, dtype: object)
# (3970, text         The day after the #GOPDebate a man who is mean...
# sentiment                                             Negative
# Name: 3970, dtype: object)
# (4410, text         RT @FrankLuntz My focus group actually likes D...
# sentiment                                             Negative
# Name: 4410, dtype: object)
# (5531, text         RT @FakeLouHoltzKSR: WHO NEEDSH THE LUCK OF TH...
# sentiment                                             Negative
# Name: 5531, dtype: object)
# (4184, text         Props to @FoxNews for the GREAT questions.  @m...
# sentiment                                             Positive
# Name: 4184, dtype: object)
# (5576, text         Rainbow wigs on fire. floppy shoes thrown asun...
# sentiment                                             Negative
# Name: 5576, dtype: object)
# (8704, text         RT @RWSurferGirl: Is it just me or does anyone...
# sentiment                                             Negative
# Name: 8704, dtype: object)
# (10024, text         RT @kwrcrow: Dr. Carson remark on DC having ha...
# sentiment                                             Positive
# ...
# sentiment                                             Negative
# Name: 11028, dtype: object)
# (9135, text         Chris Christie and Lindsey Graham seem to want...
# sentiment                                             Negative
# Name: 9135, dtype: object)
# (6253, text         Omg I hope none of them think they've heard fr...
# sentiment                                             Negative
# Name: 6253, dtype: object)
# (12046, text         RT @RWSurferGirl: You would never know @realDo...
# sentiment                                             Positive
# Name: 12046, dtype: object)
# (9061, text         RT @mette_mariek: Donald Trump is @eddiepepito...
# sentiment                                             Negative
# Name: 9061, dtype: object)
# (10049, text         RT @RWSurferGirl: It is very disappointing tha...
# sentiment                                             Negative
# Name: 10049, dtype: object)
# (9096, text         bahahaaaaaaHA!!"@RWSurferGirl: Jeb Bush remind...
# sentiment                                             Negative
# Name: 9096, dtype: object)
# (1044, text         .@realDonaldTrump Shares Post Calling Megyn Ke...
# sentiment                                             Negative
# Name: 1044, dtype: object)
# (11661, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 11661, dtype: object)
# (12088, text         RT @fieldnegro: GOP respects life....just not ...
# sentiment                                             Negative
# Name: 12088, dtype: object)
# (12039, text         RT @RWSurferGirl: Why doesn't Chris Wallace as...
# sentiment                                             Negative
# Name: 12039, dtype: object)
# (8602, text         RT @BettyFckinWhite: So Donald Trump is Biff f...
# sentiment                                             Negative
# Name: 8602, dtype: object)
# (4159, text         RT @TPEquality: Gay rights opponent Rick Santo...
# sentiment                                             Negative
# Name: 4159, dtype: object)
# (6914, text         GOP Debate News - Trump Shocks GOP Faithful ht...
# sentiment                                             Negative
# Name: 6914, dtype: object)
# (6460, text         RT @Chanlowe: #GOPDebate cartoon...#Trump @wcg...
# sentiment                                             Negative
# Name: 6460, dtype: object)
# (13312, text         #GOPDebates dumb, dumb questions. Get on with it.
# sentiment                                             Negative
# Name: 13312, dtype: object)
# (4215, text         This is mostly a left wing Democratic issue an...
# sentiment                                             Negative
# Name: 4215, dtype: object)
# (7286, text         @realDonaldTrump's narcissism got in the way o...
# sentiment                                             Negative
# Name: 7286, dtype: object)
# (4224, text         I guess I'm just grateful to Rand Paul for all...
# sentiment                                             Negative
# Name: 4224, dtype: object)
# (3909, text         Megyn Kelly was the real winner of the #GOPDEB...
# sentiment                                             Positive
# Name: 3909, dtype: object)
# (5791, text         People will watch the #GOPDebate 's to see #Tr...
# sentiment                                             Positive
# Name: 5791, dtype: object)
# (1939, text         @Marmel Wondered same thing. And Trump did men...
# sentiment                                             Negative
# Name: 1939, dtype: object)
# (8523, text         RT @larryelder: Trump should have said, "Megyn...
# sentiment                                             Negative
# Name: 8523, dtype: object)
# (8389, text         RT @RWSurferGirl: So @megynkelly posed for adu...
# sentiment                                             Negative
# Name: 8389, dtype: object)
# (9321, text         RT @DonnieWahlberg: Enjoyed the #GOPDebates an...
# sentiment                                             Positive
# Name: 9321, dtype: object)
# (1920, text         RT @2DOPEANTIBHVR: so u want us to build a wal...
# sentiment                                             Negative
# Name: 1920, dtype: object)
# (10424, text         The republican candidates are closing with the...
# sentiment                                             Negative
# Name: 10424, dtype: object)
# (11567, text         RT @SupermanHotMale: Dear #GOP, Nobody likes A...
# sentiment                                             Negative
# Name: 11567, dtype: object)
# (1857, text         RT @sydneyvl24: Cautiously optimistic is how I...
# sentiment                                             Positive
# Name: 1857, dtype: object)
# (8654, text         RT @RWSurferGirl: Is it just me or does anyone...
# sentiment                                             Negative
# Name: 8654, dtype: object)
# (9393, text         Great jobs from Mike Huckabee and Donald Trump...
# sentiment                                             Positive
# Name: 9393, dtype: object)
# (13475, text         Jeb is trying to blink the question away. #GOP...
# sentiment                                             Negative
# Name: 13475, dtype: object)
# (6875, text         #GOPDebate yes everyone had their ups and down...
# sentiment                                             Negative
# Name: 6875, dtype: object)
# (4379, text         #GOPDebate was ok Some questions were irreleva...
# sentiment                                             Negative
# Name: 4379, dtype: object)
# (1451, text         New game! 1 person CAN'T win. Players close ey...
# sentiment                                             Negative
# Name: 1451, dtype: object)
# (9722, text         Missed both #GOPDebates. Although I do not fee...
# sentiment                                             Negative
# Name: 9722, dtype: object)
# (8174, text         RT @Lrihendry: #TedCruz As President, I will a...
# sentiment                                             Positive
# Name: 8174, dtype: object)
# (11913, text         RT @Lrihendry: #TedCruz headed into the Presid...
# sentiment                                             Positive
# Name: 11913, dtype: object)
# (8047, text         Loved @BillHemmer and @marthamaccallum Ditch K...
# sentiment                                             Positive
# Name: 8047, dtype: object)
# (220, text         RT @larhunter: If Donald Trump wins the electi...
# sentiment                                             Negative
# Name: 220, dtype: object)
# (3621, text         RT @goldietaylor: Walker, surprisingly, gets i...
# sentiment                                             Positive
# Name: 3621, dtype: object)
# (5203, text         RT @YaakovSchapiro: My #GOPDebate analysis, 8)...
# sentiment                                             Positive
# Name: 5203, dtype: object)
# (13342, text         RT @RWSurferGirl: FOX News won't admit who the...
# sentiment                                             Positive
# Name: 13342, dtype: object)
# (13632, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 13632, dtype: object)
# (3339, text         RT @Didikatz: @ZeitgeistGhost #GOPDebate last ...
# sentiment                                             Negative
# Name: 3339, dtype: object)
# (637, text         RT @PamelaGeller: LOVE CRUZ! "If you join ISIS...
# sentiment                                             Positive
# Name: 637, dtype: object)
# (1103, text         RT @4BillLewis: #SocialMedia and the #FoxNews ...
# sentiment                                             Positive
# Name: 1103, dtype: object)
# (646, text         @realDonaldTrump ur complaining so much about ...
# sentiment                                             Negative
# Name: 646, dtype: object)
# (8700, text         RT @RWSurferGirl: So @megynkelly posed for adu...
# sentiment                                             Negative
# Name: 8700, dtype: object)
# (10785, text         Chris Christie: I want an unbelievably sized m...
# sentiment                                             Negative
# Name: 10785, dtype: object)
# (12365, text         RT @RWSurferGirl: The candidates don't have to...
# sentiment                                             Negative
# Name: 12365, dtype: object)
# (8492, text         RT @RWSurferGirl: Fox News is obviously trying...
# sentiment                                             Negative
# Name: 8492, dtype: object)
# (5089, text         The Master of Useful Humor\n\n#gopdebate #imwi...
# sentiment                                             Positive
# Name: 5089, dtype: object)
# (2018, text         RT @shannonrwatts: Terror Gap means terrorists...
# sentiment                                             Negative
# Name: 2018, dtype: object)
# (1394, text         @HumanityRead Who's the real illegal alien #GO...
# sentiment                                             Negative
# Name: 1394, dtype: object)
# (11714, text         RT @RWSurferGirl: Fox is cherry picking the ca...
# sentiment                                             Negative
# Name: 11714, dtype: object)
# (13199, text         RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# sentiment                                             Negative
# Name: 13199, dtype: object)
# (2153, text         RT @nochillzabree: So abortion is murder to y'...
# sentiment                                             Negative
# Name: 2153, dtype: object)
# (1766, text         RT @GrnEyedMandy: Gawd forbid any of the GOP c...
# sentiment                                             Negative
# Name: 1766, dtype: object)
# (5493, text         #GOPDebate score with @cmarinucci  https://t.c...
# sentiment                                             Positive
# Name: 5493, dtype: object)
# (2713, text         He won that debate but if you are even conside...
# sentiment                                             Negative
# Name: 2713, dtype: object)
# (13081, text         Yep, it's the pimps and drug dealers that are ...
# sentiment                                             Negative
# Name: 13081, dtype: object)
# (11342, text         RT @RWSurferGirl: Is it just me or does anyone...
# sentiment                                             Negative
# Name: 11342, dtype: object)
# (7744, text         RT @OTOOLEFAN: I figured Megyn Kelly's last qu...
# sentiment                                             Negative
# Name: 7744, dtype: object)
# (11478, text         RT @marymauldin: Hey @FoxNews ! How absolutely...
# sentiment                                             Negative
# Name: 11478, dtype: object)
# (10452, text         That last question was crap. The constitution,...
# sentiment                                             Negative
# Name: 10452, dtype: object)
# (11494, text         RT @SupermanHotMale: Hey Chris Wallace, These ...
# sentiment                                             Negative
# Name: 11494, dtype: object)
# (2549, text         I've never seen a #GOPDebate as entertaining a...
# sentiment                                             Negative
# Name: 2549, dtype: object)
# (8180, text         RT @monaeltahawy: #GOPDebates misogyny no surp...
# sentiment                                             Negative
# Name: 8180, dtype: object)
# (10520, text         You hear that, GOP candidates? Kasich said God...
# sentiment                                             Positive
# Name: 10520, dtype: object)
# (993, text         RT @Writeintrump: I not only made Hillary Clin...
# sentiment                                             Negative
# Name: 993, dtype: object)
# (333, text         Meet the new darling of the left 》 Megyn Gotch...
# sentiment                                             Negative
# Name: 333, dtype: object)
# (922, text         I have a serious #GOPDebate hangover today.
# sentiment                                       Negative
# Name: 922, dtype: object)
# (6581, text         Shame on them, they should have watched reruns...
# sentiment                                             Negative
# Name: 6581, dtype: object)
# (10891, text         RT @RWSurferGirl: Is it just me or does anyone...
# sentiment                                             Negative
# Name: 10891, dtype: object)
# (10679, text         RT @jsc1835: #GOPDebates  I'd like to see this...
# sentiment                                             Negative
# Name: 10679, dtype: object)
# (3029, text         Me while everyone was talking about the #GOPDe...
# sentiment                                             Negative
# Name: 3029, dtype: object)
# (641, text         RT @thesuperficial: "Hey, guys. Women are allo...
# sentiment                                             Negative
# Name: 641, dtype: object)
# (8635, text         RT @RWSurferGirl: So @megynkelly posed for adu...
# sentiment                                             Negative
# Name: 8635, dtype: object)
# (1315, text         RT @TC_Watkins: @DomenicoNPR @MediaEqualizer c...
# sentiment                                             Negative
# Name: 1315, dtype: object)
# (9867, text         RT @kwrcrow: Dr. Carson remark on DC having ha...
# sentiment                                             Positive
# Name: 9867, dtype: object)
# (10037, text         #Bush is an idiot.... Sadly the idiot brother ...
# sentiment                                             Negative
# Name: 10037, dtype: object)
# (9448, text         RT @kwrcrow: Dr. Carson remark on DC having ha...
# sentiment                                             Positive
# Name: 9448, dtype: object)
# (9463, text         RT @RWSurferGirl: I need to order another gree...
# sentiment                                             Negative
# Name: 9463, dtype: object)
# (4117, text         RT @Liz_Wheeler: My girl @CarlyFiorina killed ...
# sentiment                                             Positive
# Name: 4117, dtype: object)
# (6613, text         RT @PuestoLoco: .@RawStory\nFOX/GOP Party's Hu...
# sentiment                                             Negative
# Name: 6613, dtype: object)
# (12041, text         RT @RWSurferGirl: The candidates don't have to...
# sentiment                                             Negative
# Name: 12041, dtype: object)
# (10167, text         Only thing that makes Rand Paul a different ty...
# sentiment                                             Negative
# Name: 10167, dtype: object)
# (8948, text         RT @RWSurferGirl: After @GovChristie hugged Ob...
# sentiment                                             Negative
# Name: 8948, dtype: object)
# (12884, text         The only thing "illegals and prostitutes" have...
# sentiment                                             Negative
# Name: 12884, dtype: object)
# (11498, text         RT @Popehat: #GOPDebates Paul: I'm talking abo...
# sentiment                                             Negative
# Name: 11498, dtype: object)
# (8214, text         RT @RWSurferGirl: So @megynkelly posed for adu...
# sentiment                                             Negative
# Name: 8214, dtype: object)
# (10132, text         RT @steven_br: God blessed our country, the Re...
# sentiment                                             Positive
# Name: 10132, dtype: object)
# (6384, text         Today is "International Beer Day," convenientl...
# sentiment                                             Negative
# Name: 6384, dtype: object)
# (13498, text         RT @RWSurferGirl: FOX News won't admit who the...
# sentiment                                             Negative
# Name: 13498, dtype: object)
# (12573, text         RT @monaeltahawy: Can someone tell me why Ben ...
# sentiment                                             Negative
# Name: 12573, dtype: object)
# (10241, text         RT @Wilberforce91: One of my favorite things a...
# sentiment                                             Positive
# Name: 10241, dtype: object)
# (196, text         RT @LAXnOREOS: Meanwhile, in the White House.....
# sentiment                                             Negative
# Name: 196, dtype: object)
# (11470, text         RT @RWSurferGirl: Why doesn't Chris Wallace as...
# sentiment                                             Negative
# Name: 11470, dtype: object)
# (3314, text         #GOPDebate Why Pretend Hilary only Democrat Ru...
# sentiment                                             Negative
# Name: 3314, dtype: object)
