# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
os.chdir('C:\\Users\\KASTU1\\Desktop\\Analytics Path\\R\\Data')

# %%
df=pd.read_csv('carPrice.csv')
df.head()
# Out:
#    car_ID  symboling   carCompany fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase   ...     enginesize  fuelsystem  \
# 0        rwd          front       88.6   ...            130        mpfi
# 1        rwd          front       88.6   ...            130        mpfi
# 2        rwd          front       94.5   ...            152        mpfi
# 3        fwd          front       99.8   ...            109        mpfi
# 4        4wd          front       99.4   ...            136        mpfi
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
#df["carCompany"].value_counts()

# %%
df.plot(kind='scatter',x='wheelbase',y='enginesize');
plt.show()

# %%
sns.set_style('whitegrid');
sns.FacetGrid(df,hue='fueltype', size=4)\
    .map(plt.scatter,'wheelbase','enginesize')\
    .add_legend();
plt.show()
plt.close()

# %%
sns.set_style("whitegrid")
sns.pairplot(df,hue='fueltype', size=3)
plt.show()
plt.close();

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='fueltype', size=4)\
    .map(sns.distplot,'enginesize')\
    .add_legend()
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df, size=8)\
    .map(sns.distplot,'enginesize')\
    .add_legend()
plt.show()

# %%
counts, bin_edges=np.histogram(df['enginesize'],bins=15,density=False)
print(counts)
print('****************')
print(bin_edges)
print('****************')
print(sum(counts))
pdf = counts/(sum(counts))
print('******')
print(pdf);
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,'r',label='CDF',linewidth=5.0)
plt.plot(bin_edges[1:],cdf,label='PDF')
plt.grid
plt.legend()
plt.ylabel('Counts')
plt.xlabel('Engine Size')
plt.show
# Out:
# [ 4 34 63 35 25 16 14  3  4  2  0  2  0  2  1]
# ****************
# [ 61.          78.66666667  96.33333333 114.         131.66666667
#  149.33333333 167.         184.66666667 202.33333333 220.
#  237.66666667 255.33333333 273.         290.66666667 308.33333333
#  326.        ]
# ****************
# 205
# ******
# [0.0195122  0.16585366 0.30731707 0.17073171 0.12195122 0.07804878
#  0.06829268 0.01463415 0.0195122  0.0097561  0.         0.0097561
#  0.         0.0097561  0.00487805]
# <function matplotlib.pyplot.show>
