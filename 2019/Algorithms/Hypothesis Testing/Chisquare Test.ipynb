# %% [markdown]
# https://www.mathsisfun.com/data/chi-square-test.html

# %% [markdown]
# https://www.google.com/search?q=chi+square+table+right+tail&tbm=isch&source=iu&ictx=1&fir=dMgEZGSHCd8c9M%253A%252COg5MZSWthOLWJM%252C_&vet=1&usg=AI4_-kRTdKjmW8VszkSSuFSt9RJAOJ_FUQ&sa=X&ved=2ahUKEwj07uuD-4nkAhXIinAKHT2fAZEQ9QEwB3oECAUQEg#imgrc=hsvRW4grNgPouM:&vet=1

# %% [markdown]
# https://www.google.com/search?q=chi+square+table+right+tail&tbm=isch&source=iu&ictx=1&fir=dMgEZGSHCd8c9M%253A%252COg5MZSWthOLWJM%252C_&vet=1&usg=AI4_-kRTdKjmW8VszkSSuFSt9RJAOJ_FUQ&sa=X&ved=2ahUKEwj07uuD-4nkAhXIinAKHT2fAZEQ9QEwB3oECAUQEg#imgrc=U8iuaiD_01wPAM:&vet=1

# %% [markdown]
# https://www.spss-tutorials.com/chi-square-independence-test/

# %% [markdown]
# Table
#
# https://www.google.com/search?q=chi+square+table+right+tail&tbm=isch&source=iu&ictx=1&fir=dMgEZGSHCd8c9M%253A%252COg5MZSWthOLWJM%252C_&vet=1&usg=AI4_-kRTdKjmW8VszkSSuFSt9RJAOJ_FUQ&sa=X&ved=2ahUKEwj07uuD-4nkAhXIinAKHT2fAZEQ9QEwB3oECAUQEg#imgrc=hsvRW4grNgPouM:&vet=1

# %%
# import all the libraries which are required
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir('C:\\Users\\prudi\\Desktop\\Data Sets\\House Pricing Dataset\\housing-prices-dataset') # Place the correct working folder
#os.chdir('C:\\Users\\Administrator\\Desktop\\Data')

# %%
## Read the data
hp=pd.read_csv('HousePricingDataset.csv') ## Put the right dataset name

# %%
# Run this set of code
hp.loc[hp['LotFrontage'].isnull(),'LotFrontage']=np.mean(hp['LotFrontage'])
hp.loc[hp['Alley'].isnull(),'Alley']='No Alley'
hp.loc[hp['BsmtQual'].isnull(),'BsmtQual']='No Bsmt'
hp.loc[hp['BsmtCond'].isnull(),'BsmtCond']='No Bsmt'
hp.loc[hp['BsmtExposure'].isnull(),'BsmtExposure']='No Bsmt'
hp.loc[hp['BsmtFinType1'].isnull(),'BsmtFinType1']='No Bsmt'
hp.loc[hp['BsmtFinType2'].isnull(),'BsmtFinType2']='No Bsmt'
hp.loc[hp['GarageType'].isnull(),'GarageType']='No Garage'
hp.loc[hp['GarageYrBlt'].isnull(),'GarageYrBlt']= 9999
hp.loc[hp['GarageFinish'].isnull(),'GarageFinish']='No Garage'
hp.loc[hp['GarageQual'].isnull(),'GarageQual']='No Garage'
hp.loc[hp['GarageCond'].isnull(),'GarageCond']='No Garage'
hp.loc[hp['PoolQC'].isnull(),'PoolQC']='No Pool'
hp.loc[hp['Fence'].isnull(),'Fence']='No Fence'
hp.loc[hp['FireplaceQu'].isnull(),'FireplaceQu']='No Fireplace'

# %%
# Apply this set of code for the ordinal variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(hp['Alley'])
le_alley=pd.DataFrame(le.transform(hp['Alley']),columns=['Alley_Transformed'])
hp= pd.concat([hp, le_alley],axis=1)
hp.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  No Alley      Reg
# 1   2          20       RL         80.0     9600   Pave  No Alley      Reg
# 2   3          60       RL         68.0    11250   Pave  No Alley      IR1
# 3   4          70       RL         60.0     9550   Pave  No Alley      IR1
# 4   5          60       RL         84.0    14260   Pave  No Alley      IR1
#
#   LandContour Utilities  ...   PoolQC     Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...  No Pool  No Fence         NaN       0      2
# 1         Lvl    AllPub  ...  No Pool  No Fence         NaN       0      5
# 2         Lvl    AllPub  ...  No Pool  No Fence         NaN       0      9
# 3         Lvl    AllPub  ...  No Pool  No Fence         NaN       0      2
# 4         Lvl    AllPub  ...  No Pool  No Fence         NaN       0     12
#
#   YrSold SaleType  SaleCondition  SalePrice  Alley_Transformed
# ...

# %%
# Apply this set of code for the ordinal variable
from sklearn.preprocessing import LabelEncoder
le_saletype = LabelEncoder()
le_saletype.fit(hp['SaleType'])
le_saletype=pd.DataFrame(le_saletype.transform(hp['SaleType']),columns=['SaleType_Transformed'])
hp= pd.concat([hp, le_saletype],axis=1)
hp.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  No Alley      Reg
# 1   2          20       RL         80.0     9600   Pave  No Alley      Reg
# 2   3          60       RL         68.0    11250   Pave  No Alley      IR1
# 3   4          70       RL         60.0     9550   Pave  No Alley      IR1
# 4   5          60       RL         84.0    14260   Pave  No Alley      IR1
#
#   LandContour Utilities  ...     Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...  No Fence         NaN       0      2   2008
# 1         Lvl    AllPub  ...  No Fence         NaN       0      5   2007
# 2         Lvl    AllPub  ...  No Fence         NaN       0      9   2008
# 3         Lvl    AllPub  ...  No Fence         NaN       0      2   2006
# 4         Lvl    AllPub  ...  No Fence         NaN       0     12   2008
#
# ...

# %%
hp.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  No Alley      Reg
# 1   2          20       RL         80.0     9600   Pave  No Alley      Reg
# 2   3          60       RL         68.0    11250   Pave  No Alley      IR1
# 3   4          70       RL         60.0     9550   Pave  No Alley      IR1
# 4   5          60       RL         84.0    14260   Pave  No Alley      IR1
#
#   LandContour Utilities  ...     Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...  No Fence         NaN       0      2   2008
# 1         Lvl    AllPub  ...  No Fence         NaN       0      5   2007
# 2         Lvl    AllPub  ...  No Fence         NaN       0      9   2008
# 3         Lvl    AllPub  ...  No Fence         NaN       0      2   2006
# 4         Lvl    AllPub  ...  No Fence         NaN       0     12   2008
#
# ...

# %%
from sklearn.feature_selection import chi2
f_score = chi2(np.array(hp['Alley_Transformed']).reshape(-1,1), np.array(hp['Alley_Transformed']).reshape(-1,1))
f_score
# Out:
# (array([91.50861475]), array([1.34634631e-20]))

# %%
hp['Alley_Transformed'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
hp['SaleType_Transformed'].unique()
# Out:
# array([8, 6, 0, 3, 4, 1, 5, 2, 7], dtype=int64)

# %%
contingency_table = pd.crosstab(
    hp['Alley_Transformed'],
    hp['SaleType_Transformed'],
    margins = True
)
contingency_table
# Out:
# SaleType_Transformed   0  1  2  3  4  5    6  7     8   All
# Alley_Transformed
# 0                      2  1  0  0  1  0    0  0    46    50
# 1                     40  3  2  9  4  5  115  3  1188  1369
# 2                      1  0  0  0  0  0    7  0    33    41
# All                   43  4  2  9  5  5  122  3  1267  1460

# %%
malecount = contingency_table.iloc[0][0:9].values
femalecount = contingency_table.iloc[1][0:9].values

#Plots the bar chart
fig = plt.figure(figsize=(10, 5))
sns.set(font_scale=1.8)
categories = ["0","1","2","3","4","5","6","7","8"]
p1 = plt.bar(categories, malecount, 0.55, color='#d62728')
p2 = plt.bar(categories, femalecount, 0.55, bottom=malecount)
plt.legend((p2[0], p1[0]), ('Male', 'Female'))
plt.xlabel('Hours per Week Worked')
plt.ylabel('Count')
plt.show()

# %%
f_obs = np.array([contingency_table.iloc[0][0:9].values,
                  contingency_table.iloc[1][0:9].values,
                 contingency_table.iloc[2][0:9].values])
f_obs
# Out:
# array([[   2,    1,    0,    0,    1,    0,    0,    0,   46],
#        [  40,    3,    2,    9,    4,    5,  115,    3, 1188],
#        [   1,    0,    0,    0,    0,    0,    7,    0,   33]],
#       dtype=int64)

# %%
from scipy import stats
stats.chi2_contingency(f_obs)
# Out:
# (19.6959523246811,
#  0.23422806520374556,
#  16,
#  array([[1.47260274e+00, 1.36986301e-01, 6.84931507e-02, 3.08219178e-01,
#          1.71232877e-01, 1.71232877e-01, 4.17808219e+00, 1.02739726e-01,
#          4.33904110e+01],
#         [4.03198630e+01, 3.75068493e+00, 1.87534247e+00, 8.43904110e+00,
#          4.68835616e+00, 4.68835616e+00, 1.14395890e+02, 2.81301370e+00,
#          1.18802945e+03],
#         [1.20753425e+00, 1.12328767e-01, 5.61643836e-02, 2.52739726e-01,
#          1.40410959e-01, 1.40410959e-01, 3.42602740e+00, 8.42465753e-02,
#          3.55801370e+01]]))

# %%
from scipy.stats import chi2_contingency
stat, p, dof, expected = chi2_contingency(hp['Alley_Transformed'],hp['Alley_Transformed'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-06d5991e0154> in <module>
#       1 from scipy.stats import chi2_contingency
# ----> 2 stat, p, dof, expected = chi2_contingency(hp['Alley_Transformed'],hp['Alley_Transformed'])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\contingency.py in chi2_contingency(observed, correction, lambda_)
#     252         zeropos = list(zip(*np.nonzero(expected == 0)))[0]
#     253         raise ValueError("The internally computed table of expected "
# --> 254                          "frequencies has a zero element at %s." % (zeropos,))
#     255
#     256     # The degrees of freedom
#
# ValueError: The internally computed table of expected frequencies has a zero element at (21,).
